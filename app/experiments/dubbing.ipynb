# %%
import os
import shutil
from google.cloud import speech, translate_v2 as translate, texttospeech
from pydub import AudioSegment
from pydub.silence import split_on_silence
from moviepy.editor import VideoFileClip, AudioFileClip

# --- Configuration ---
# Find language codes here: https://cloud.google.com/speech-to-text/docs/languages
SOURCE_LANGUAGE_CODE = "en-US"  # English (United States)
TARGET_LANGUAGE_CODE = "es"     # Spanish
TARGET_TTS_VOICE_NAME = "es-ES-Wavenet-B" # Spanish (Spain) voice, find more here: https://cloud.google.com/text-to-speech/docs/voices

# --- Main Dubbing Function ---

def dub_movie(video_path, output_path):
    """
    Main function to dub a video from a source language to a target language.
    """
    print("--- Starting Movie Dubbing Process ---")

    # Create a temporary directory for intermediate files
    temp_dir = "temp_dubbing_files"
    if os.path.exists(temp_dir):
        shutil.rmtree(temp_dir)
    os.makedirs(temp_dir)

    try:
        # 1. Extract Audio from Video
        print("\n[Step 1/7] Extracting audio from video...")
        original_audio_path = os.path.join(temp_dir, "original_audio.wav")
        video_clip = VideoFileClip(video_path)
        video_clip.audio.write_audiofile(original_audio_path, codec='pcm_s16le') # Use WAV for pydub
        print(f"Successfully extracted audio to {original_audio_path}")

        # 2. Split Audio on Silence
        print("\n[Step 2/7] Splitting audio into chunks based on silence...")
        audio = AudioSegment.from_wav(original_audio_path)
        audio_chunks = split_on_silence(
            audio,
            min_silence_len=700,      # Minimum silence length in ms
            silence_thresh=-40,       # Silence threshold in dBFS
            keep_silence=400          # Keep some silence at the end of chunks
        )
        if not audio_chunks:
            print("Could not split audio. The audio might be too quiet or have no silence.")
            return

        chunk_paths = []
        for i, chunk in enumerate(audio_chunks):
            chunk_path = os.path.join(temp_dir, f"chunk_{i}.wav")
            chunk.export(chunk_path, format="wav")
            chunk_paths.append(chunk_path)
        print(f"Split audio into {len(chunk_paths)} chunks.")

        # 3, 4, 5: Process each chunk (Transcribe -> Translate -> Synthesize)
        dubbed_chunk_paths = []
        for i, chunk_path in enumerate(chunk_paths):
            print(f"\n--- Processing Chunk {i+1}/{len(chunk_paths)} ---")
            
            # 3. Transcribe
            print(f"[Step 3/7] Transcribing chunk {i+1}...")
            original_text = transcribe_audio_chunk(chunk_path, SOURCE_LANGUAGE_CODE)
            if not original_text:
                print("Transcription failed or returned no text. Skipping chunk.")
                # To maintain timing, we create a silent audio chunk of the same duration
                original_chunk_duration = len(AudioSegment.from_wav(chunk_path))
                silent_chunk = AudioSegment.silent(duration=original_chunk_duration)
                dubbed_chunk_path = os.path.join(temp_dir, f"dubbed_chunk_{i}.wav")
                silent_chunk.export(dubbed_chunk_path, format="wav")
                dubbed_chunk_paths.append(dubbed_chunk_path)
                continue

            print(f"  > Original Text: {original_text}")

            # 4. Translate
            print(f"[Step 4/7] Translating chunk {i+1}...")
            translated_text = translate_text(original_text, TARGET_LANGUAGE_CODE, SOURCE_LANGUAGE_CODE.split('-')[0])
            print(f"  > Translated Text: {translated_text}")

            # 5. Synthesize Speech
            print(f"[Step 5/7] Synthesizing speech for chunk {i+1}...")
            dubbed_chunk_path = os.path.join(temp_dir, f"dubbed_chunk_{i}.wav")
            synthesize_speech(translated_text, TARGET_LANGUAGE_CODE, TARGET_TTS_VOICE_NAME, dubbed_chunk_path)
            dubbed_chunk_paths.append(dubbed_chunk_path)
            print(f"  > Synthesized audio saved to {dubbed_chunk_path}")

        # 6. Combine Dubbed Audio Chunks
        print("\n[Step 6/7] Combining all dubbed audio chunks...")
        final_dubbed_audio = AudioSegment.empty()
        for path in dubbed_chunk_paths:
            final_dubbed_audio += AudioSegment.from_wav(path)
        
        final_audio_path = os.path.join(temp_dir, "final_dubbed_audio.mp3")
        final_dubbed_audio.export(final_audio_path, format="mp3")
        print(f"Final dubbed audio track created at {final_audio_path}")

        # 7. Merge new audio with original video
        print("\n[Step 7/7] Merging dubbed audio with the original video...")
        final_audio_clip = AudioFileClip(final_audio_path)
        # Set the video's audio to the new dubbed audio
        final_video = video_clip.set_audio(final_audio_clip)
        final_video.write_videofile(output_path, codec="libx264", audio_codec="aac")
        print(f"--- SUCCESS! Dubbed movie saved to {output_path} ---")

    except Exception as e:
        print(f"\nAn error occurred: {e}")
    finally:
        # Clean up temporary files
        if os.path.exists(temp_dir):
            print("\nCleaning up temporary files...")
            # shutil.rmtree(temp_dir) # Uncomment to automatically delete temp files

# --- Helper Functions for Google Cloud APIs ---

def transcribe_audio_chunk(chunk_path, language_code):
    """Transcribes a single audio chunk using Google Speech-to-Text."""
    client = speech.SpeechClient()
    with open(chunk_path, "rb") as audio_file:
        content = audio_file.read()
    
    audio = speech.RecognitionAudio(content=content)
    config = speech.RecognitionConfig(
        encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,
        sample_rate_hertz=AudioSegment.from_wav(chunk_path).frame_rate,
        language_code=language_code,
    )
    
    response = client.recognize(config=config, audio=audio)
    
    if response.results:
        return response.results[0].alternatives[0].transcript
    return ""

def translate_text(text, target_language, source_language):
    """Translates text using Google Translation API."""
    client = translate.Client()
    result = client.translate(text, target_language=target_language, source_language=source_language)
    return result["translatedText"]

def synthesize_speech(text, language_code, voice_name, output_filename):
    """Synthesizes speech from text using Google Text-to-Speech."""
    client = texttospeech.TextToSpeechClient()
    
    input_text = texttospeech.SynthesisInput(text=text)
    
    voice = texttospeech.VoiceSelectionParams(
        language_code=language_code, name=voice_name
    )
    
    audio_config = texttospeech.AudioConfig(
        audio_encoding=texttospeech.AudioEncoding.LINEAR16 # Use WAV for easy concatenation
    )
    
    response = client.synthesize_speech(
        input=input_text, voice=voice, audio_config=audio_config
    )
    
    with open(output_filename, "wb") as out:
        out.write(response.audio_content)

# --- Main execution block ---

if __name__ == "__main__":
    # Ensure you have a short video clip (e.g., 15-30 seconds) for testing
    # Long movies will take a lot of time and may be costly
    input_video_file = "input.mp4" 
    output_video_file = "dubbed_output.mp4"

    if not os.path.exists(input_video_file):
        print(f"Error: Input video file not found at '{input_video_file}'")
        print("Please place a video file named 'input.mp4' in the same directory as the script.")
    else:
        dub_movie(input_video_file, output_video_file)

# %%
import os
import shutil
import math
from google.cloud import speech, translate_v2 as translate, texttospeech
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip, CompositeAudioClip
from spleeter.separator import Separator

# --- Configuration ---
SOURCE_LANGUAGE_CODE = "en-US"  # Language of the original video
TARGET_LANGUAGE_CODE = "es"     # Language to dub into
TARGET_LANGUAGE_TRANSLATE = "es" # Google Translate uses 'es', not 'es-ES'

# Map speaker tags from diarization to specific TTS voices
# Find voice names here: https://cloud.google.com/text-to-speech/docs/voices
# Add more speakers and voices as needed.
SPEAKER_VOICES = {
    1: {"name": "es-ES-Wavenet-B", "gender": "MALE"},    # Speaker 1 -> Spanish Male
    2: {"name": "es-ES-Wavenet-C", "gender": "FEMALE"},  # Speaker 2 -> Spanish Female
    # Default/fallback voice for any other speakers found
    "default": {"name": "es-ES-Wavenet-D", "gender": "MALE"},
}
SPLEETER_MODEL = 'spleeter:2stems' # Model for separating vocals from accompaniment

# --- Main Dubbing Function ---

def dub_movie_advanced(video_path, output_path):
    """
    Main function to dub a video using advanced techniques:
    - Vocal separation with Spleeter
    - Speaker diarization
    - Dynamic timing adjustment
    """
    print("--- Starting Advanced Movie Dubbing Process ---")
    
    # Create a temporary directory
    temp_dir = "temp_advanced_dubbing"
    if os.path.exists(temp_dir):
        shutil.rmtree(temp_dir)
    os.makedirs(temp_dir)

    try:
        # 1. Extract Full Audio from Video
        print("\n[Step 1/8] Extracting full audio track...")
        original_audio_path = os.path.join(temp_dir, "original_audio.wav")
        video_clip = VideoFileClip(video_path)
        video_clip.audio.write_audiofile(original_audio_path, codec='pcm_s16le')
        print(f"  > Full audio saved to {original_audio_path}")

        # 2. Separate Vocals from Background Music using Spleeter
        print("\n[Step 2/8] Separating vocals from background music...")
        vocals_path, background_path = separate_audio_components(original_audio_path, temp_dir)
        print(f"  > Vocals saved to: {vocals_path}")
        print(f"  > Background music saved to: {background_path}")

        # 3. Transcribe with Speaker Diarization
        print("\n[Step 3/8] Transcribing vocals with speaker identification...")
        diarized_segments = transcribe_with_diarization(vocals_path, SOURCE_LANGUAGE_CODE)
        if not diarized_segments:
            print("  > No speech detected or diarization failed. Aborting.")
            return
        print(f"  > Transcription complete. Found {len(diarized_segments)} speech segments.")

        # 4. Translate and Synthesize each segment
        print("\n[Step 4-6/8] Translating, Synthesizing, and Adjusting Timing for each segment...")
        # Create a silent audio track with the same duration as the original vocals
        original_vocal_audio = AudioSegment.from_wav(vocals_path)
        dubbed_vocal_track = AudioSegment.silent(duration=len(original_vocal_audio))

        for i, segment in enumerate(diarized_segments):
            text, start_time, end_time, speaker_tag = segment['text'], segment['start'], segment['end'], segment['speaker']
            print(f"\n--- Processing Segment {i+1}/{len(diarized_segments)} (Speaker {speaker_tag}) ---")
            print(f"  > Original Text: {text}")

            # 4. Translate
            translated_text = translate_text(text, TARGET_LANGUAGE_TRANSLATE, SOURCE_LANGUAGE_CODE.split('-')[0])
            print(f"  > Translated Text: {translated_text}")

            # 5. Synthesize Speech with the correct voice
            voice_config = SPEAKER_VOICES.get(speaker_tag, SPEAKER_VOICES["default"])
            dubbed_segment_path = os.path.join(temp_dir, f"dubbed_segment_{i}.wav")

            # Here you could add logic to use SSML for emotional tone
            # For simplicity, we use standard synthesis. See synthesize_speech_ssml for an example.
            synthesize_speech(translated_text, TARGET_LANGUAGE_CODE, voice_config["name"], dubbed_segment_path)
            
            # 6. Adjust Timing
            dubbed_segment_audio = AudioSegment.from_wav(dubbed_segment_path)
            original_duration = (end_time - start_time) * 1000  # in ms
            
            adjusted_audio = adjust_audio_speed(dubbed_segment_audio, original_duration)
            
            # Overlay the adjusted audio onto the main dubbed vocal track at the correct start time
            dubbed_vocal_track = dubbed_vocal_track.overlay(adjusted_audio, position=start_time * 1000)
            print(f"  > Segment timing adjusted and placed on track at {start_time:.2f}s.")

        dubbed_vocals_path = os.path.join(temp_dir, "final_dubbed_vocals.wav")
        dubbed_vocal_track.export(dubbed_vocals_path, format="wav")
        print("\n  > Full dubbed vocal track created.")

        # 7. Merge Dubbed Vocals with Original Background Music
        print("\n[Step 7/8] Merging dubbed vocals with original background track...")
        background_audio = AudioSegment.from_wav(background_path)
        final_audio = background_audio.overlay(dubbed_vocal_track)
        
        final_audio_path = os.path.join(temp_dir, "final_dubbed_audio.mp3")
        final_audio.export(final_audio_path, format="mp3")
        print(f"  > Final audio mix created at {final_audio_path}")
        
        # 8. Merge Final Audio with Original Video
        print("\n[Step 8/8] Merging final audio with the video...")
        final_audio_clip = AudioFileClip(final_audio_path)
        final_video = video_clip.set_audio(final_audio_clip)
        final_video.write_videofile(output_path, codec="libx264", audio_codec="aac")
        
        print(f"\n--- SUCCESS! Advanced dubbed movie saved to {output_path} ---")

    except Exception as e:
        print(f"\nAn error occurred: {e}")
        import traceback
        traceback.print_exc()
    finally:
        # Clean up
        if os.path.exists(temp_dir):
            # shutil.rmtree(temp_dir) # Uncomment to auto-delete temp files
            print("\nTemporary files kept in 'temp_advanced_dubbing' for inspection.")


# --- Helper Functions ---

def separate_audio_components(audio_path, output_dir):
    """Separates audio into vocals and accompaniment using Spleeter."""
    separator = Separator(SPLEETER_MODEL)
    separator.separate_to_file(audio_path, output_dir)
    
    # Spleeter creates a folder named after the input file
    input_filename = os.path.splitext(os.path.basename(audio_path))[0]
    spleeter_output_dir = os.path.join(output_dir, input_filename)
    
    vocals_path = os.path.join(spleeter_output_dir, "vocals.wav")
    background_path = os.path.join(spleeter_output_dir, "accompaniment.wav")
    
    if not os.path.exists(vocals_path) or not os.path.exists(background_path):
        raise FileNotFoundError("Spleeter did not produce the expected output files.")
        
    return vocals_path, background_path

def transcribe_with_diarization(audio_path, language_code):
    """Transcribes audio and identifies speakers."""
    client = speech.SpeechClient()
    with open(audio_path, "rb") as audio_file:
        content = audio_file.read()

    audio = speech.RecognitionAudio(content=content)
    # Get audio properties for accurate config
    audio_segment = AudioSegment.from_wav(audio_path)
    
    config = speech.RecognitionConfig(
        encoding=speech.RecognitionConfig.AudioEncoding.LINEAR16,
        sample_rate_hertz=audio_segment.frame_rate,
        language_code=language_code,
        enable_speaker_diarization=True,
        diarization_speaker_count=len(SPEAKER_VOICES) -1 # Let Google know how many speakers to look for
    )

    print("  > Sending audio to Google for transcription (this may take a while)...")
    operation = client.long_running_recognize(config=config, audio=audio)
    response = operation.result(timeout=900) # Timeout in seconds

    # Process diarization results
    result = response.results[-1] # The last result has the full transcript
    words_info = result.alternatives[0].words
    
    segments = []
    current_segment = None

    for word_info in words_info:
        speaker_tag = word_info.speaker_tag
        if current_segment is None or current_segment['speaker'] != speaker_tag:
            # End previous segment
            if current_segment:
                current_segment['end'] = word_info.start_time.total_seconds()
                segments.append(current_segment)
            # Start new segment
            current_segment = {
                'speaker': speaker_tag,
                'start': word_info.start_time.total_seconds(),
                'text': word_info.word
            }
        else:
            current_segment['text'] += " " + word_info.word
    
    # Add the last segment
    if current_segment:
        current_segment['end'] = words_info[-1].end_time.total_seconds()
        segments.append(current_segment)
        
    return segments

def adjust_audio_speed(audio_segment, target_duration_ms):
    """Speeds up or slows down an audio segment to match a target duration."""
    original_duration_ms = len(audio_segment)
    if original_duration_ms == 0 or target_duration_ms == 0:
        return audio_segment

    speed_ratio = original_duration_ms / target_duration_ms
    
    if abs(1.0 - speed_ratio) < 0.01: # Don't adjust if already very close
        return audio_segment

    print(f"    - Adjusting speed. Original: {original_duration_ms}ms, Target: {target_duration_ms}ms, Ratio: {speed_ratio:.2f}")
    # speedup() in pydub requires a playback_speed > 1 for faster, < 1 for slower
    # Our ratio is inverted, so we use it directly.
    return audio_segment.speedup(playback_speed=speed_ratio)


# The standard helper functions from before, with an added SSML example
def translate_text(text, target, source):
    client = translate.Client()
    result = client.translate(text, target_language=target, source_language=source)
    return result["translatedText"]

def synthesize_speech(text, lang_code, voice_name, output_file):
    client = texttospeech.TextToSpeechClient()
    synthesis_input = texttospeech.SynthesisInput(text=text)
    voice = texttospeech.VoiceSelectionParams(language_code=lang_code, name=voice_name)
    audio_config = texttospeech.AudioConfig(audio_encoding=texttospeech.AudioEncoding.LINEAR16)
    response = client.synthesize_speech(input=synthesis_input, voice=voice, audio_config=audio_config)
    with open(output_file, "wb") as out:
        out.write(response.audio_content)

def synthesize_speech_ssml(ssml_text, lang_code, voice_name, output_file):
    """Synthesizes speech from SSML text for more expressive control."""
    client = texttospeech.TextToSpeechClient()
    synthesis_input = texttospeech.SynthesisInput(ssml=ssml_text)
    voice = texttospeech.VoiceSelectionParams(language_code=lang_code, name=voice_name)
    audio_config = texttospeech.AudioConfig(audio_encoding=texttospeech.AudioEncoding.LINEAR16)
    response = client.synthesize_speech(input=synthesis_input, voice=voice, audio_config=audio_config)
    with open(output_file, "wb") as out:
        out.write(response.audio_content)

# --- Execution Block ---

if __name__ == "__main__":
    input_video = "input.mp4"
    output_video = "dubbed_advanced_output.mp4"

    if not os.path.exists(input_video):
        print(f"Error: Input video '{input_video}' not found.")
    else:
        dub_movie_advanced(input_video, output_video)

# %%
import os
import shutil
import subprocess
from elevenlabs.client import ElevenLabs
from elevenlabs import Voice, VoiceSettings
from google.cloud import translate_v2 as translate
from pydub import AudioSegment
from moviepy.editor import VideoFileClip, AudioFileClip
from spleeter.separator import Separator

# --- Configuration ---
# Google Cloud
SOURCE_LANGUAGE_CODE = "en-US"
TARGET_LANGUAGE_CODE = "es-ES"
TARGET_LANGUAGE_TRANSLATE = "es"

# ElevenLabs (Replace with your API Key)
ELEVENLABS_API_KEY = "YOUR_ELEVENLABS_API_KEY"
if ELEVENLABS_API_KEY == "YOUR_ELEVENLABS_API_KEY":
    raise ValueError("Please replace 'YOUR_ELEVENLABS_API_KEY' with your actual ElevenLabs API key.")
client = ElevenLabs(api_key=ELEVENLABS_API_KEY)

# File Paths
SPLEETER_MODEL = 'spleeter:2stems'
WAV2LIP_PATH = "Wav2Lip" # Path to the cloned Wav2Lip directory

# --- Main Professional Dubbing Function ---

def dub_movie_professional(video_path, output_path):
    print("--- Starting Professional-Grade Movie Dubbing ---")
    
    temp_dir = "temp_professional_dubbing"
    if os.path.exists(temp_dir): shutil.rmtree(temp_dir)
    os.makedirs(temp_dir)

    try:
        # 1. Extract and Separate Audio
        print("\n[Step 1/5] Extracting and Separating Audio...")
        original_audio_path = os.path.join(temp_dir, "original_audio.wav")
        video_clip = VideoFileClip(video_path)
        video_clip.audio.write_audiofile(original_audio_path, codec='pcm_s16le')
        vocals_path, background_path = separate_audio_components(original_audio_path, temp_dir)
        print("  > Audio separation complete.")

        # 2. Transcribe and Diarize (using our previous function)
        print("\n[Step 2/5] Transcribing and Identifying Speakers...")
        # Note: We're reusing the Google-based diarization function. It's good enough for this.
        from advanced_dubber import transcribe_with_diarization # Assuming you have the previous script
        diarized_segments = transcribe_with_diarization(vocals_path, SOURCE_LANGUAGE_CODE)
        if not diarized_segments:
            print("  > No speech detected. Aborting.")
            return
        print(f"  > Transcription complete. Found {len(diarized_segments)} speech segments.")

        # 3. Clone Voices, Translate, and Synthesize with Emotion
        print("\n[Step 3/5] Cloning Voices, Translating, and Synthesizing...")
        original_vocal_audio = AudioSegment.from_wav(vocals_path)
        dubbed_vocal_track = AudioSegment.silent(duration=len(original_vocal_audio))
        cloned_voices = {}

        for i, segment in enumerate(diarized_segments):
            speaker_tag = segment['speaker']
            print(f"\n--- Processing Segment {i+1}/{len(diarized_segments)} (Speaker {speaker_tag}) ---")

            # A. Clone voice if we haven't seen this speaker before
            if speaker_tag not in cloned_voices:
                print(f"  > New speaker detected (Tag {speaker_tag}). Cloning voice...")
                start_ms = int(segment['start'] * 1000)
                end_ms = int(segment['end'] * 1000)
                # Take a sample of the speaker's voice for cloning
                voice_sample_audio = original_vocal_audio[start_ms:end_ms]
                sample_path = os.path.join(temp_dir, f"speaker_{speaker_tag}_sample.wav")
                voice_sample_audio.export(sample_path, format="wav")
                
                cloned_voices[speaker_tag] = client.voices.add(
                    name=f"ClonedSpeaker_{speaker_tag}",
                    description=f"Auto-cloned voice for speaker {speaker_tag}",
                    files=[sample_path],
                )
                print(f"  > Voice cloned successfully. Voice ID: {cloned_voices[speaker_tag].voice_id}")

            # B. Translate text
            translated_text = translate_text(segment['text'], TARGET_LANGUAGE_TRANSLATE, SOURCE_LANGUAGE_CODE.split('-')[0])
            print(f"  > Translated: {translated_text}")

            # C. Synthesize with the cloned voice
            voice_to_use = cloned_voices[speaker_tag]
            audio_response = client.generate(
                text=translated_text,
                voice=Voice(
                    voice_id=voice_to_use.voice_id,
                    settings=VoiceSettings(stability=0.5, similarity_boost=0.75, style=0.1, use_speaker_boost=True)
                ),
                model="eleven_multilingual_v2"
            )
            
            dubbed_segment_path = os.path.join(temp_dir, f"dubbed_segment_{i}.mp3")
            with open(dubbed_segment_path, "wb") as f:
                f.write(audio_response)

            # D. Adjust timing and overlay
            dubbed_segment_audio = AudioSegment.from_mp3(dubbed_segment_path)
            original_duration = (segment['end'] - segment['start']) * 1000
            adjusted_audio = adjust_audio_speed(dubbed_segment_audio, original_duration)
            dubbed_vocal_track = dubbed_vocal_track.overlay(adjusted_audio, position=segment['start'] * 1000)
        
        # 4. Create Final Pre-Lip-Sync Video
        print("\n[Step 4/5] Merging final audio to create pre-sync video...")
        dubbed_vocals_path = os.path.join(temp_dir, "final_dubbed_vocals.wav")
        dubbed_vocal_track.export(dubbed_vocals_path, format="wav")

        background_audio = AudioSegment.from_wav(background_path)
        final_audio = background_audio.overlay(dubbed_vocal_track)
        
        final_audio_path = os.path.join(temp_dir, "final_dubbed_audio.wav") # Use WAV for Wav2Lip
        final_audio.export(final_audio_path, format="wav")

        pre_sync_video_path = os.path.join(temp_dir, "video_presync.mp4")
        final_audio_clip = AudioFileClip(final_audio_path)
        video_clip.set_audio(final_audio_clip).write_videofile(pre_sync_video_path, codec="libx264", audio_codec="aac")
        print(f"  > Pre-sync video created at: {pre_sync_video_path}")

        # 5. Execute Wav2Lip for Final Lip-Sync
        print("\n[Step 5/5] Executing Wav2Lip for final lip-sync (this will take a long time)...")
        run_wav2lip(pre_sync_video_path, final_audio_path, output_path)
        
        print(f"\n--- SUCCESS! Professionally dubbed and lip-synced movie saved to {output_path} ---")

    except Exception as e:
        print(f"\nAn error occurred: {e}")
        import traceback
        traceback.print_exc()
    finally:
        # Clean up cloned voices from ElevenLabs account to avoid clutter
        if 'cloned_voices' in locals():
            for speaker_tag, voice in cloned_voices.items():
                print(f"Cleaning up cloned voice for speaker {speaker_tag}...")
                client.voices.delete(voice.voice_id)
        # shutil.rmtree(temp_dir) # Uncomment for auto-cleanup


# --- Helper Functions (Re-used and New) ---

def separate_audio_components(audio_path, output_dir):
    separator = Separator(SPLEETER_MODEL)
    separator.separate_to_file(audio_path, output_dir, codec='wav')
    input_filename = os.path.splitext(os.path.basename(audio_path))[0]
    spleeter_output_dir = os.path.join(output_dir, input_filename)
    return os.path.join(spleeter_output_dir, "vocals.wav"), os.path.join(spleeter_output_dir, "accompaniment.wav")

def translate_text(text, target, source):
    client = translate.Client()
    return client.translate(text, target_language=target, source_language=source)["translatedText"]

def adjust_audio_speed(audio_segment, target_duration_ms):
    ratio = len(audio_segment) / target_duration_ms
    return audio_segment.speedup(playback_speed=ratio) if ratio > 0 else audio_segment

def run_wav2lip(video_path, audio_path, output_path):
    """Executes the Wav2Lip inference script using a subprocess."""
    checkpoint = os.path.join(WAV2LIP_PATH, 'checkpoints', 'wav2lip_gan.pth')
    
    # Ensure paths are absolute for the subprocess
    video_path_abs = os.path.abspath(video_path)
    audio_path_abs = os.path.abspath(audio_path)
    output_path_abs = os.path.abspath(output_path)
    
    # Command to run. Adjust padding if faces are cut off.
    command = [
        'python', 'inference.py',
        '--checkpoint_path', checkpoint,
        '--face', video_path_abs,
        '--audio', audio_path_abs,
        '--outfile', output_path_abs,
        # '--pads', '0', '20', '0', '0' # Example padding: top, bottom, left, right
    ]
    
    print(f"  > Running command: {' '.join(command)}")
    # We run this from within the Wav2Lip directory
    subprocess.run(command, cwd=WAV2LIP_PATH, check=True)

# --- Execution Block ---

if __name__ == "__main__":
    # Import the diarization function from our previous script
    # This assumes 'advanced_dubber.py' is in the same directory.
    try:
        from advanced_dubber import transcribe_with_diarization
    except ImportError:
        print("\nERROR: Could not import 'transcribe_with_diarization'.")
        print("Please ensure the 'advanced_dubber.py' script from the previous step is in the same directory.\n")
        exit()

    input_video = "input.mp4"
    output_video = "dubbed_professional_output.mp4"

    if not os.path.exists(input_video):
        print(f"Error: Input video '{input_video}' not found.")
    elif not os.path.exists(WAV2LIP_PATH):
        print(f"Error: Wav2Lip directory not found at '{WAV2LIP_PATH}'.")
    else:
        dub_movie_professional(input_video, output_video)

# %%
import requests

API_KEY = ""  # or set via environment variable ELEVENLABS_API_KEY
AUDIO_PATH = "/home/csc/Documents/Multilingual-Transcriber/shared_data/movieslist/rishtey/audio_files/rishtey_part5__audio.mp3"  # support WAV, MP3, etc.

url = "https://api.elevenlabs.io/v1/speech-to-text"
headers = {
    "xi-api-key": API_KEY
}

with open(AUDIO_PATH, "rb") as f:
    files = {
        "file": f
    }
    data = {
        "model_id": "scribe_v1",
        "diarize": True
    }
    response = requests.post(url, headers=headers, data=data, files=files)

result = response.json()

# Print full transcript
print("\nFull Transcript:\n", result.get("text", ""))

# Print diarized segments
if "words" in result:
    for w in result["words"]:
        start = w.get("start", 0)
        end = w.get("end", 0)
        speaker = w.get("speaker", w.get("speaker_id", "Unknown"))
        text = w.get("text", "")
        if text:
            print(f"[{start:.2f}s - {end:.2f}s] Speaker {speaker}: {text}")
# Out:
# Full Transcript:
#  (परिचय गीत बजता है) तुम ना होते तो एक भी कदम मैं तो चलता नहीं। तुमसे ही मिली है मुझे आज एक नई जिंदगी। सच मैं कहता हूं इस जहां में है तुम सा कोई नहीं। एक पल के लिए तुम्हारे बिन मुझको जीना नहीं। हो मेरी जान तुम पापा। मेरे भगवान तुम पापा। (क्लोज़ की ध्वनि) (पृष्ठभूमि में संगीत बजता है) (पत्थर के घड़से से जूझ रहे हैं) (ध्वनि प्रभाव) अरे प्यारे अंकल आप मुझे कहां लेकर जा रहे हो? ओए तू चलता सही। एँठे खड़ा जा, एँठे खड़ा जा। उहहह हाँ उहदेख! (पृष्ठभूमि में संगीत बजता है) (हंसते हुए) थैंक यू पापा, थैंक यू सो मच। यू लाइक आईटी? या आई रियली लाइक आईटी। चलाएगा? हाँ पापा। समाज सिट। आह, रेडी? येस। ओके? ओके। कम ऑन, लेट्स गो। यस! हाँ कर्न्ट, कर्न्ट। शाबाश, शाबाश करण, शाबाश। हाँ, हाँ डरना मत, डर मा, डर मा। कम ऑन टर्न, टर्न, टर्न, टर्न। अब मैं चला लूंगा। प-प-पेता तू गिरेगा। पापा छोड़िए मैं खुद चला लूंगा। नहीं बेटा तू गिर जाएगा, संभाल के। पापा प्लीज छोड़िये। छोड़ूं मैं? हाँ प्लीज। ओके। संभाल के करण, संभाल के। अरे किसी को ठोक, ठोक मत करना। अरे वो साधा होता है संभाल के चला देगा, तू चिंता काहे को करता है? करण! चल चल, चल लस्सी पीते हैं। (खर्च की आवाज़) पॉपलेट वाली पॉपलेट, ताजा ताजा पॉपलेट। पॉपलेट। (दाऊल की आवाज़) मोटा मोटा ड्राई फ्रूट्स। (चिल्लाती हुई आवाज़) अरे कुछ लेके आओ इस आदमी के। अरे ब्रेक में नहीं सकता मैं ब्रेक तो। अरे तू जी भाजी टंका। अरे बाबा। डॉली! अरे नीचे को देख, नीचे के पीछे को देख। ट्राट। आइगा! सत्यानाश हो तेरा हलकट। मेरा पूरा मच्छर गिरा है ना। छोडूंगी ना मैं तेरे को। हलकट कहां से गिरा? अरे घोड़-घोड़े से धारा पकड़ ला। (स्टीयरिंग के चाके गिरने की आवाज आती है) अरे थाप! अरे डॉली खाओ नारे, नारे। अरे घोड़े से कहां से गिरे? (लोग चिल्लाते हुए) सॉरी डॉली। तेरे को। अरे ठेकेदार थाप! (हीट से गीली छवि किरण आ जाने की आवाज आती है) आइला सॉरी अंकल। (हंसते हुए) इधर से गिर जाए, उधर से गिर जाए। अरे ढींगे! हाँ, हाँ। (लात मारने की आवाज आती है) अभी तू बच के कहां जाएगा? हाँ, क्यों अरे ढींगे? अब तू आया ना मेरे नेट में। अब देख मैं कैसे तेरा छील कर निकलती है। माफ करना गलती हो गई मौसी। मौसी! उन्नीस साल की लड़की को मौसी बुलाता है। मैं तेरी मां की बहन लगती है क्या? तेरे को तान्हा। हवलदार! किधर है? हवलदार किधर है? हाँ, बता देवर को भी तुमने कुछ भी किया, मैं उसे छोडूंगी नहीं। (लात मारने की आवाज आती है) अरे जगा, अरे वो आंको ना वो, वो आंको। (लात मारने की आवाज आती है) अरे तेरे को मैं छोडूंगी नहीं। संभाल। अरे गवाया, अरे गोली तेरी मार दूं। एक मिनट, एक मिनट, एक मिनट। अरे, अरे देखिए, देखिए मेरी बात सुनिए। (लड़की चिल्लाती हुई) अरे ए, ए हाथ दबाई क्यों रही हो? (लड़की चिल्लाती हुई) अरे भाग क्यों रही हो? (लड़की चिल्लाती हुई) अरे, अरे रुको, रुको, रुको। मैं तुम्हारी मदद करने की कोशिश कर रहा हूं। अरे जल्दी निकलो मेरे को सांस नहीं आ रहा है। अरे आ जाएगी तुम सीधी खड़ी रहो। एक मिनट। (लड़की सांस लेती हुए) अरे अटक गया। अरे जल्दी निकल दो। अरे ये हैंडा अटक कैसे गया? (किसी चीज को तोड़ते हुए) आह, आह। (लड़की सांस लेती है) हा, हा। (गाना गाया जाता है) ही ही ही ही ही ही ही ही ही ही ही ही ही ही ही ही ही ही ही। लागा लगा के इंकार, पानी की बट्टी में गया। लागा लगा के इंकार, पानी की बट्टी में गया। (बैकग्राउंड में संगीत बजता है) सॉरी। माफी काहे को मांगता है? अच्छा लगा मिल तो।
# [0.00s - 1.18s] Speaker speaker_0: (परिचय गीत बजता है)
# [1.18s - 3.84s] Speaker speaker_0:
# [3.84s - 4.26s] Speaker speaker_0: तुम
# [4.26s - 4.40s] Speaker speaker_0:
# [4.40s - 4.58s] Speaker speaker_0: ना
# [4.58s - 4.76s] Speaker speaker_0:
# [4.76s - 5.64s] Speaker speaker_0: होते
# [5.64s - 5.76s] Speaker speaker_0:
# [5.76s - 6.08s] Speaker speaker_0: तो
# [6.08s - 6.10s] Speaker speaker_0:
# [6.10s - 6.66s] Speaker speaker_0: एक
# [6.66s - 6.86s] Speaker speaker_0:
# [6.86s - 7.28s] Speaker speaker_0: भी
# [7.28s - 7.38s] Speaker speaker_0:
# [7.38s - 7.94s] Speaker speaker_0: कदम
# [7.94s - 8.32s] Speaker speaker_0:
# [8.32s - 8.70s] Speaker speaker_0: मैं
# [8.70s - 8.78s] Speaker speaker_0:
# [8.78s - 9.00s] Speaker speaker_0: तो
# [9.00s - 9.10s] Speaker speaker_0:
# [9.10s - 10.02s] Speaker speaker_0: चलता
# [10.02s - 10.14s] Speaker speaker_0:
# [10.14s - 12.24s] Speaker speaker_0: नहीं।
# [12.24s - 12.64s] Speaker speaker_0:
# [12.64s - 13.42s] Speaker speaker_0: तुमसे
# [13.42s - 13.52s] Speaker speaker_0:
# [13.52s - 13.94s] Speaker speaker_0: ही
# [13.94s - 14.04s] Speaker speaker_0:
# [14.04s - 14.72s] Speaker speaker_0: मिली
# [14.72s - 14.82s] Speaker speaker_0:
# [14.82s - 15.26s] Speaker speaker_0: है
# [15.26s - 15.38s] Speaker speaker_0:
# [15.38s - 15.92s] Speaker speaker_0: मुझे
# [15.92s - 16.26s] Speaker speaker_0:
# [16.26s - 16.90s] Speaker speaker_0: आज
# [16.90s - 17.04s] Speaker speaker_0:
# [17.04s - 17.38s] Speaker speaker_0: एक
# [17.38s - 17.56s] Speaker speaker_0:
# [17.56s - 18.26s] Speaker speaker_0: नई
# [18.26s - 18.38s] Speaker speaker_0:
# [18.38s - 20.06s] Speaker speaker_0: जिंदगी।
# [20.06s - 21.34s] Speaker speaker_0:
# [21.34s - 21.78s] Speaker speaker_0: सच
# [21.78s - 21.92s] Speaker speaker_0:
# [21.92s - 22.12s] Speaker speaker_0: मैं
# [22.12s - 22.22s] Speaker speaker_0:
# [22.22s - 23.18s] Speaker speaker_0: कहता
# [23.18s - 23.32s] Speaker speaker_0:
# [23.32s - 23.56s] Speaker speaker_0: हूं
# [23.56s - 23.64s] Speaker speaker_0:
# [23.64s - 24.06s] Speaker speaker_0: इस
# [24.06s - 24.12s] Speaker speaker_0:
# [24.12s - 24.90s] Speaker speaker_0: जहां
# [24.90s - 24.96s] Speaker speaker_0:
# [24.96s - 25.18s] Speaker speaker_0: में
# [25.18s - 25.22s] Speaker speaker_0:
# [25.22s - 25.44s] Speaker speaker_0: है
# [25.44s - 25.80s] Speaker speaker_0:
# [25.80s - 26.24s] Speaker speaker_0: तुम
# [26.24s - 26.34s] Speaker speaker_0:
# [26.34s - 26.60s] Speaker speaker_0: सा
# [26.60s - 26.68s] Speaker speaker_0:
# [26.68s - 27.64s] Speaker speaker_0: कोई
# [27.64s - 27.76s] Speaker speaker_0:
# [27.76s - 29.10s] Speaker speaker_0: नहीं।
# [29.10s - 30.22s] Speaker speaker_0:
# [30.22s - 30.78s] Speaker speaker_0: एक
# [30.78s - 31.00s] Speaker speaker_0:
# [31.00s - 31.38s] Speaker speaker_0: पल
# [31.38s - 31.52s] Speaker speaker_0:
# [31.52s - 31.96s] Speaker speaker_0: के
# [31.96s - 32.00s] Speaker speaker_0:
# [32.00s - 32.74s] Speaker speaker_0: लिए
# [32.74s - 32.86s] Speaker speaker_0:
# [32.86s - 33.92s] Speaker speaker_0: तुम्हारे
# [33.92s - 33.98s] Speaker speaker_0:
# [33.98s - 34.24s] Speaker speaker_0: बिन
# [34.24s - 34.58s] Speaker speaker_0:
# [34.58s - 35.38s] Speaker speaker_0: मुझको
# [35.38s - 35.40s] Speaker speaker_0:
# [35.40s - 36.34s] Speaker speaker_0: जीना
# [36.34s - 36.40s] Speaker speaker_0:
# [36.40s - 37.16s] Speaker speaker_0: नहीं।
# [37.16s - 37.58s] Speaker speaker_0:
# [37.58s - 37.80s] Speaker speaker_0: हो
# [37.80s - 37.86s] Speaker speaker_0:
# [37.86s - 38.82s] Speaker speaker_0: मेरी
# [38.82s - 38.94s] Speaker speaker_0:
# [38.94s - 39.94s] Speaker speaker_0: जान
# [39.94s - 40.02s] Speaker speaker_0:
# [40.02s - 40.30s] Speaker speaker_0: तुम
# [40.30s - 40.60s] Speaker speaker_0:
# [40.60s - 41.62s] Speaker speaker_0: पापा।
# [41.62s - 42.00s] Speaker speaker_0:
# [42.00s - 42.64s] Speaker speaker_0: मेरे
# [42.64s - 42.74s] Speaker speaker_0:
# [42.74s - 44.30s] Speaker speaker_0: भगवान
# [44.30s - 44.42s] Speaker speaker_0:
# [44.42s - 44.70s] Speaker speaker_0: तुम
# [44.70s - 45.00s] Speaker speaker_0:
# [45.00s - 46.34s] Speaker speaker_0: पापा।
# [46.34s - 46.40s] Speaker speaker_0:
# [46.40s - 47.24s] Speaker speaker_0: (क्लोज़ की ध्वनि)
# [47.24s - 47.24s] Speaker speaker_0:
# [47.24s - 47.24s] Speaker speaker_0: (पृष्ठभूमि में संगीत बजता है)
# [47.24s - 47.24s] Speaker speaker_0:
# [47.24s - 47.84s] Speaker speaker_0: (पत्थर के घड़से से जूझ रहे हैं)
# [47.84s - 47.84s] Speaker speaker_0:
# [47.84s - 47.86s] Speaker speaker_0: (ध्वनि प्रभाव)
# [47.86s - 47.86s] Speaker speaker_0:
# [47.86s - 47.96s] Speaker speaker_0: अरे
# [47.96s - 47.96s] Speaker speaker_0:
# [47.96s - 49.72s] Speaker speaker_0: प्यारे
# [49.72s - 50.02s] Speaker speaker_0:
# [50.02s - 50.38s] Speaker speaker_0: अंकल
# [50.38s - 50.38s] Speaker speaker_0:
# [50.38s - 50.56s] Speaker speaker_0: आप
# [50.56s - 51.42s] Speaker speaker_0:
# [51.42s - 51.44s] Speaker speaker_0: मुझे
# [51.44s - 51.44s] Speaker speaker_0:
# [51.44s - 51.54s] Speaker speaker_0: कहां
# [51.54s - 51.54s] Speaker speaker_0:
# [51.54s - 51.54s] Speaker speaker_0: लेकर
# [51.54s - 51.54s] Speaker speaker_0:
# [51.54s - 51.62s] Speaker speaker_0: जा
# [51.62s - 51.62s] Speaker speaker_0:
# [51.62s - 51.86s] Speaker speaker_0: रहे
# [51.86s - 51.86s] Speaker speaker_0:
# [51.86s - 51.88s] Speaker speaker_0: हो?
# [51.88s - 51.88s] Speaker speaker_0:
# [51.88s - 51.88s] Speaker speaker_1: ओए
# [51.88s - 51.88s] Speaker speaker_1:
# [51.88s - 51.88s] Speaker speaker_1: तू
# [51.88s - 51.88s] Speaker speaker_1:
# [51.88s - 51.88s] Speaker speaker_1: चलता
# [51.88s - 51.88s] Speaker speaker_1:
# [51.88s - 51.88s] Speaker speaker_1: सही।
# [51.88s - 51.98s] Speaker speaker_1:
# [51.98s - 52.02s] Speaker speaker_1: एँठे
# [52.02s - 52.02s] Speaker speaker_1:
# [52.02s - 52.02s] Speaker speaker_1: खड़ा
# [52.02s - 52.02s] Speaker speaker_1:
# [52.02s - 52.02s] Speaker speaker_1: जा,
# [52.02s - 52.02s] Speaker speaker_1:
# [52.02s - 52.02s] Speaker speaker_1: एँठे
# [52.02s - 52.02s] Speaker speaker_1:
# [52.02s - 52.02s] Speaker speaker_1: खड़ा
# [52.02s - 52.02s] Speaker speaker_1:
# [52.02s - 52.02s] Speaker speaker_1: जा।
# [52.02s - 52.02s] Speaker speaker_1:
# [52.02s - 52.28s] Speaker speaker_1: उहहह
# [52.28s - 52.28s] Speaker speaker_1:
# [52.28s - 52.30s] Speaker speaker_1: हाँ
# [52.30s - 52.30s] Speaker speaker_1:
# [52.30s - 52.34s] Speaker speaker_1: उहदेख!
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: (पृष्ठभूमि में संगीत बजता है)
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: (हंसते हुए)
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_0: थैंक
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: यू
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: पापा,
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: थैंक
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: यू
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: सो
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: मच।
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_1: यू
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: लाइक
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: आईटी?
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_0: या
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: आई
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: रियली
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: लाइक
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: आईटी।
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_1: चलाएगा?
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_0: हाँ
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: पापा।
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_1: समाज
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: सिट।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: आह,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: रेडी?
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_0: येस।
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_1: ओके?
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_0: ओके।
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_1: कम
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: ऑन,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: लेट्स
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: गो।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: यस!
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: हाँ
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: कर्न्ट,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: कर्न्ट।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: शाबाश,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: शाबाश
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: करण,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: शाबाश।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: हाँ,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: हाँ
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: डरना
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: मत,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: डर
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: मा,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: डर
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: मा।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: कम
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: ऑन
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: टर्न,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: टर्न,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: टर्न,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: टर्न।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_0: अब
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: मैं
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: चला
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: लूंगा।
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_1: प-प-पेता
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: तू
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: गिरेगा।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_0: पापा
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: छोड़िए
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: मैं
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: खुद
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: चला
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: लूंगा।
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_1: नहीं
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: बेटा
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: तू
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: गिर
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: जाएगा,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: संभाल
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: के।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_0: पापा
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: प्लीज
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: छोड़िये।
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_1: छोड़ूं
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: मैं?
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_0: हाँ
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: प्लीज।
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_1: ओके।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: संभाल
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: के
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: करण,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: संभाल
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: के।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: अरे
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: किसी
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: को
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: ठोक,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: ठोक
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: मत
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: करना।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_2: अरे
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: वो
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: साधा
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: होता
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: है
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: संभाल
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: के
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: चला
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: देगा,
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: तू
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: चिंता
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: काहे
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: को
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: करता
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: है?
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_1: करण!
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_2: चल
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: चल,
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: चल
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: लस्सी
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: पीते
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: हैं।
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_2: (खर्च की आवाज़)
# [52.34s - 52.34s] Speaker speaker_2:
# [52.34s - 52.34s] Speaker speaker_3: पॉपलेट
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: वाली
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: पॉपलेट,
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: ताजा
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: ताजा
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: पॉपलेट।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: पॉपलेट।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: (दाऊल की आवाज़)
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: मोटा
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: मोटा
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: ड्राई
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: फ्रूट्स।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: (चिल्लाती हुई आवाज़)
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: कुछ
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: लेके
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: आओ
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: इस
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: आदमी
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: के।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: ब्रेक
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: में
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: नहीं
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: सकता
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: मैं
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: ब्रेक
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: तो।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: तू
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: जी
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: भाजी
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: टंका।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: बाबा।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_1: डॉली!
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: नीचे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: को
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: देख,
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: नीचे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: के
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: पीछे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: को
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: देख।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: ट्राट।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: आइगा!
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: सत्यानाश
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: हो
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: तेरा
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: हलकट।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: मेरा
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: पूरा
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: मच्छर
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: गिरा
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: है
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: ना।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: छोडूंगी
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: ना
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: मैं
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: तेरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: को।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: हलकट
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: कहां
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: से
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: गिरा?
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: घोड़-घोड़े
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: से
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: धारा
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: पकड़
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: ला।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: (स्टीयरिंग के चाके गिरने की आवाज आती है)
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: थाप!
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_1: अरे
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: डॉली
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: खाओ
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: नारे,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: नारे।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: घोड़े
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: से
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: कहां
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: से
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: गिरे?
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: (लोग चिल्लाते हुए)
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_1: सॉरी
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: डॉली।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_3: तेरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: को।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: ठेकेदार
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: थाप!
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: (हीट से गीली छवि किरण आ जाने की आवाज आती है)
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: आइला
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: सॉरी
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: अंकल।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_1: (हंसते हुए)
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: इधर
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: से
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: गिर
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: जाए,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: उधर
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: से
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: गिर
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: जाए।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: ढींगे!
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: हाँ,
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: हाँ।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: (लात मारने की आवाज आती है)
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: अभी
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: तू
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: बच
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: के
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: कहां
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: जाएगा?
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: हाँ,
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: क्यों
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: ढींगे?
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: अब
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: तू
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: आया
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: ना
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: मेरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: नेट
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: में।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: अब
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: देख
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: मैं
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: कैसे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: तेरा
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: छील
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: कर
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: निकलती
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: है।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_0: माफ
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: करना
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: गलती
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: हो
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: गई
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_0: मौसी।
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_3: मौसी!
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: उन्नीस
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: साल
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: की
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: लड़की
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: को
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: मौसी
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: बुलाता
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: है।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: मैं
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: तेरी
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: मां
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: की
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: बहन
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: लगती
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: है
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: क्या?
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: तेरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: को
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: तान्हा।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_0: हवलदार!
# [52.34s - 52.34s] Speaker speaker_0:
# [52.34s - 52.34s] Speaker speaker_3: किधर
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: है?
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: हवलदार
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: किधर
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: है?
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: हाँ,
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: बता
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: देवर
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: को
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: भी
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: तुमने
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: कुछ
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: भी
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: किया,
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: मैं
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: उसे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: छोडूंगी
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: नहीं।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: (लात मारने की आवाज आती है)
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: जगा,
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: वो
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: आंको
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: ना
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: वो,
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: वो
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: आंको।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: (लात मारने की आवाज आती है)
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: तेरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: को
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: मैं
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: छोडूंगी
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: नहीं।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_1: संभाल।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: गवाया,
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: गोली
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: तेरी
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: मार
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_3: दूं।
# [52.34s - 52.34s] Speaker speaker_3:
# [52.34s - 52.34s] Speaker speaker_1: एक
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: मिनट,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: एक
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: मिनट,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: एक
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: मिनट।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: अरे,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: अरे
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: देखिए,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: देखिए
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: मेरी
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: बात
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: सुनिए।
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: (लड़की चिल्लाती हुई)
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: अरे
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: ए,
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: ए
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: हाथ
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: दबाई
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: क्यों
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: रही
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: हो?
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: (लड़की चिल्लाती हुई)
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: अरे
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: भाग
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: क्यों
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: रही
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.34s] Speaker speaker_1: हो?
# [52.34s - 52.34s] Speaker speaker_1:
# [52.34s - 52.68s] Speaker speaker_1: (लड़की चिल्लाती हुई)
# [52.68s - 52.68s] Speaker speaker_1:
# [52.68s - 52.68s] Speaker speaker_1: अरे,
# [52.68s - 52.68s] Speaker speaker_1:
# [52.68s - 52.68s] Speaker speaker_1: अरे
# [52.68s - 52.68s] Speaker speaker_1:
# [52.68s - 52.68s] Speaker speaker_1: रुको,
# [52.68s - 52.68s] Speaker speaker_1:
# [52.68s - 52.68s] Speaker speaker_1: रुको,
# [52.68s - 52.68s] Speaker speaker_1:
# [52.68s - 52.68s] Speaker speaker_1: रुको।
# [52.68s - 52.68s] Speaker speaker_1:
# [52.68s - 52.68s] Speaker speaker_1: मैं
# [52.68s - 52.68s] Speaker speaker_1:
# [52.68s - 52.68s] Speaker speaker_1: तुम्हारी
# [52.68s - 52.68s] Speaker speaker_1:
# [52.68s - 52.70s] Speaker speaker_1: मदद
# [52.70s - 52.70s] Speaker speaker_1:
# [52.70s - 52.72s] Speaker speaker_1: करने
# [52.72s - 53.16s] Speaker speaker_1:
# [53.16s - 53.18s] Speaker speaker_1: की
# [53.18s - 53.18s] Speaker speaker_1:
# [53.18s - 53.18s] Speaker speaker_1: कोशिश
# [53.18s - 53.18s] Speaker speaker_1:
# [53.18s - 53.18s] Speaker speaker_1: कर
# [53.18s - 53.18s] Speaker speaker_1:
# [53.18s - 53.18s] Speaker speaker_1: रहा
# [53.18s - 53.18s] Speaker speaker_1:
# [53.18s - 53.18s] Speaker speaker_1: हूं।
# [53.18s - 53.18s] Speaker speaker_1:
# [53.18s - 53.18s] Speaker speaker_3: अरे
# [53.18s - 53.18s] Speaker speaker_3:
# [53.18s - 53.18s] Speaker speaker_3: जल्दी
# [53.18s - 53.18s] Speaker speaker_3:
# [53.18s - 85.16s] Speaker speaker_3: निकलो
# [85.16s - 101.54s] Speaker speaker_3:
# [101.54s - 176.26s] Speaker speaker_3: मेरे
# [176.26s - 176.26s] Speaker speaker_3:
# [176.26s - 176.46s] Speaker speaker_3: को
# [176.46s - 176.76s] Speaker speaker_3:
# [176.76s - 186.84s] Speaker speaker_3: सांस
# [186.84s - 203.78s] Speaker speaker_3:
# [203.78s - 254.06s] Speaker speaker_3: नहीं
# [254.06s - 254.08s] Speaker speaker_3:
# [254.08s - 254.20s] Speaker speaker_3: आ
# [254.20s - 254.20s] Speaker speaker_3:
# [254.20s - 254.36s] Speaker speaker_3: रहा
# [254.36s - 254.36s] Speaker speaker_3:
# [254.36s - 255.04s] Speaker speaker_3: है।
# [255.04s - 255.04s] Speaker speaker_3:
# [255.04s - 255.20s] Speaker speaker_1: अरे
# [255.20s - 255.22s] Speaker speaker_1:
# [255.22s - 255.40s] Speaker speaker_1: आ
# [255.40s - 255.42s] Speaker speaker_1:
# [255.42s - 255.66s] Speaker speaker_1: जाएगी
# [255.66s - 255.66s] Speaker speaker_1:
# [255.66s - 255.82s] Speaker speaker_1: तुम
# [255.82s - 255.82s] Speaker speaker_1:
# [255.82s - 256.06s] Speaker speaker_1: सीधी
# [256.06s - 256.08s] Speaker speaker_1:
# [256.08s - 256.28s] Speaker speaker_1: खड़ी
# [256.28s - 256.28s] Speaker speaker_1:
# [256.28s - 256.72s] Speaker speaker_1: रहो।
# [256.72s - 256.74s] Speaker speaker_1:
# [256.74s - 256.94s] Speaker speaker_1: एक
# [256.94s - 256.96s] Speaker speaker_1:
# [256.96s - 257.32s] Speaker speaker_1: मिनट।
# [257.32s - 257.32s] Speaker speaker_1:
# [257.32s - 259.56s] Speaker speaker_3: (लड़की सांस लेती हुए)
# [259.56s - 259.56s] Speaker speaker_3:
# [259.56s - 259.72s] Speaker speaker_3: अरे
# [259.72s - 259.74s] Speaker speaker_3:
# [259.74s - 260.14s] Speaker speaker_3: अटक
# [260.14s - 260.14s] Speaker speaker_3:
# [260.14s - 261.84s] Speaker speaker_3: गया।
# [261.84s - 261.84s] Speaker speaker_3:
# [261.84s - 262.46s] Speaker speaker_3: अरे
# [262.46s - 262.48s] Speaker speaker_3:
# [262.48s - 262.84s] Speaker speaker_3: जल्दी
# [262.84s - 262.86s] Speaker speaker_3:
# [262.86s - 263.18s] Speaker speaker_3: निकल
# [263.18s - 263.18s] Speaker speaker_3:
# [263.18s - 263.80s] Speaker speaker_3: दो।
# [263.80s - 263.80s] Speaker speaker_3:
# [263.80s - 264.74s] Speaker speaker_1: अरे
# [264.74s - 264.74s] Speaker speaker_1:
# [264.74s - 264.86s] Speaker speaker_1: ये
# [264.86s - 264.86s] Speaker speaker_1:
# [264.86s - 265.12s] Speaker speaker_1: हैंडा
# [265.12s - 265.14s] Speaker speaker_1:
# [265.14s - 265.44s] Speaker speaker_1: अटक
# [265.44s - 265.44s] Speaker speaker_1:
# [265.44s - 265.70s] Speaker speaker_1: कैसे
# [265.70s - 265.70s] Speaker speaker_1:
# [265.70s - 265.98s] Speaker speaker_1: गया?
# [265.98s - 268.08s] Speaker speaker_1:
# [268.08s - 268.36s] Speaker speaker_1: (किसी चीज को तोड़ते हुए)
# [268.36s - 268.36s] Speaker speaker_1:
# [268.36s - 268.52s] Speaker speaker_1: आह,
# [268.52s - 269.22s] Speaker speaker_1:
# [269.22s - 272.14s] Speaker speaker_1: आह।
# [272.14s - 272.14s] Speaker speaker_1:
# [272.14s - 273.40s] Speaker speaker_3: (लड़की सांस लेती है)
# [273.40s - 273.40s] Speaker speaker_3:
# [273.40s - 273.42s] Speaker speaker_3: हा,
# [273.42s - 273.52s] Speaker speaker_3:
# [273.52s - 273.92s] Speaker speaker_3: हा।
# [273.92s - 273.92s] Speaker speaker_3:
# [273.92s - 273.94s] Speaker speaker_4: (गाना गाया जाता है)
# [273.94s - 274.98s] Speaker speaker_4:
# [274.98s - 275.00s] Speaker speaker_4: ही
# [275.00s - 275.02s] Speaker speaker_4:
# [275.02s - 275.22s] Speaker speaker_4: ही
# [275.22s - 275.22s] Speaker speaker_4:
# [275.22s - 275.24s] Speaker speaker_4: ही
# [275.24s - 275.24s] Speaker speaker_4:
# [275.24s - 275.24s] Speaker speaker_4: ही
# [275.24s - 275.24s] Speaker speaker_4:
# [275.24s - 275.24s] Speaker speaker_4: ही
# [275.24s - 275.24s] Speaker speaker_4:
# [275.24s - 275.24s] Speaker speaker_4: ही
# [275.24s - 275.40s] Speaker speaker_4:
# [275.40s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4:
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4:
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4:
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4:
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4:
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4:
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4:
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4:
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4:
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4:
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4:
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 276.60s] Speaker speaker_4:
# [276.60s - 276.84s] Speaker speaker_4: ही।
# [276.84s - 276.88s] Speaker speaker_4:
# [276.88s - 277.32s] Speaker speaker_4: लागा
# [277.32s - 277.36s] Speaker speaker_4:
# [277.36s - 277.88s] Speaker speaker_4: लगा
# [277.88s - 277.88s] Speaker speaker_4:
# [277.88s - 277.98s] Speaker speaker_4: के
# [277.98s - 277.98s] Speaker speaker_4:
# [277.98s - 278.00s] Speaker speaker_4: इंकार,
# [278.00s - 278.00s] Speaker speaker_4:
# [278.00s - 278.00s] Speaker speaker_4: पानी
# [278.00s - 278.00s] Speaker speaker_4:
# [278.00s - 278.00s] Speaker speaker_4: की
# [278.00s - 278.04s] Speaker speaker_4:
# [278.04s - 283.72s] Speaker speaker_4: बट्टी
# [283.72s - 283.72s] Speaker speaker_4:
# [283.72s - 283.74s] Speaker speaker_4: में
# [283.74s - 283.74s] Speaker speaker_4:
# [283.74s - 285.46s] Speaker speaker_4: गया।
# [285.46s - 285.50s] Speaker speaker_4:
# [285.50s - 285.90s] Speaker speaker_4: लागा
# [285.90s - 286.14s] Speaker speaker_4:
# [286.14s - 286.30s] Speaker speaker_4: लगा
# [286.30s - 286.34s] Speaker speaker_4:
# [286.34s - 286.46s] Speaker speaker_4: के
# [286.46s - 286.74s] Speaker speaker_4:
# [286.74s - 287.26s] Speaker speaker_4: इंकार,
# [287.26s - 287.72s] Speaker speaker_4:
# [287.72s - 288.08s] Speaker speaker_4: पानी
# [288.08s - 288.20s] Speaker speaker_4:
# [288.20s - 288.34s] Speaker speaker_4: की
# [288.34s - 288.54s] Speaker speaker_4:
# [288.54s - 288.66s] Speaker speaker_4: बट्टी
# [288.66s - 288.70s] Speaker speaker_4:
# [288.70s - 289.28s] Speaker speaker_4: में
# [289.28s - 289.48s] Speaker speaker_4:
# [289.48s - 289.50s] Speaker speaker_4: गया।
# [289.50s - 289.50s] Speaker speaker_4:
# [289.50s - 296.18s] Speaker speaker_4: (बैकग्राउंड में संगीत बजता है)
# [296.18s - 296.18s] Speaker speaker_4:
# [296.18s - 297.58s] Speaker speaker_1: सॉरी।
# [297.58s - 297.58s] Speaker speaker_1:
# [297.58s - 297.90s] Speaker speaker_0: माफी
# [297.90s - 297.90s] Speaker speaker_0:
# [297.90s - 298.00s] Speaker speaker_0: काहे
# [298.00s - 298.02s] Speaker speaker_0:
# [298.02s - 298.08s] Speaker speaker_0: को
# [298.08s - 298.10s] Speaker speaker_0:
# [298.10s - 298.44s] Speaker speaker_0: मांगता
# [298.44s - 298.44s] Speaker speaker_0:
# [298.44s - 298.62s] Speaker speaker_0: है?
# [298.62s - 299.32s] Speaker speaker_0:
# [299.32s - 299.68s] Speaker speaker_0: अच्छा
# [299.68s - 299.74s] Speaker speaker_0:
# [299.74s - 299.92s] Speaker speaker_0: लगा
# [299.92s - 299.94s] Speaker speaker_0:
# [299.94s - 299.98s] Speaker speaker_0: मिल
# [299.98s - 299.98s] Speaker speaker_0:
# [299.98s - 299.98s] Speaker speaker_0: तो।

# %%
# Print diarized segments
if "words" in result:
    for w in result["words"]:
        start = w.get("start", 0)
        end = w.get("end", 0)
        speaker = w.get("speaker", w.get("speaker_id", "Unknown"))
        text = w.get("text", "")
        if len(text) > 1  :
            print(f"[{start:.2f}s - {end:.2f}s] Speaker {speaker}: {text}")
# Out:
# [0.00s - 1.18s] Speaker speaker_0: (परिचय गीत बजता है)
# [3.84s - 4.26s] Speaker speaker_0: तुम
# [4.40s - 4.58s] Speaker speaker_0: ना
# [4.76s - 5.64s] Speaker speaker_0: होते
# [5.76s - 6.08s] Speaker speaker_0: तो
# [6.10s - 6.66s] Speaker speaker_0: एक
# [6.86s - 7.28s] Speaker speaker_0: भी
# [7.38s - 7.94s] Speaker speaker_0: कदम
# [8.32s - 8.70s] Speaker speaker_0: मैं
# [8.78s - 9.00s] Speaker speaker_0: तो
# [9.10s - 10.02s] Speaker speaker_0: चलता
# [10.14s - 12.24s] Speaker speaker_0: नहीं।
# [12.64s - 13.42s] Speaker speaker_0: तुमसे
# [13.52s - 13.94s] Speaker speaker_0: ही
# [14.04s - 14.72s] Speaker speaker_0: मिली
# [14.82s - 15.26s] Speaker speaker_0: है
# [15.38s - 15.92s] Speaker speaker_0: मुझे
# [16.26s - 16.90s] Speaker speaker_0: आज
# [17.04s - 17.38s] Speaker speaker_0: एक
# [17.56s - 18.26s] Speaker speaker_0: नई
# [18.38s - 20.06s] Speaker speaker_0: जिंदगी।
# [21.34s - 21.78s] Speaker speaker_0: सच
# [21.92s - 22.12s] Speaker speaker_0: मैं
# [22.22s - 23.18s] Speaker speaker_0: कहता
# [23.32s - 23.56s] Speaker speaker_0: हूं
# [23.64s - 24.06s] Speaker speaker_0: इस
# [24.12s - 24.90s] Speaker speaker_0: जहां
# [24.96s - 25.18s] Speaker speaker_0: में
# [25.22s - 25.44s] Speaker speaker_0: है
# [25.80s - 26.24s] Speaker speaker_0: तुम
# [26.34s - 26.60s] Speaker speaker_0: सा
# [26.68s - 27.64s] Speaker speaker_0: कोई
# [27.76s - 29.10s] Speaker speaker_0: नहीं।
# [30.22s - 30.78s] Speaker speaker_0: एक
# [31.00s - 31.38s] Speaker speaker_0: पल
# [31.52s - 31.96s] Speaker speaker_0: के
# [32.00s - 32.74s] Speaker speaker_0: लिए
# [32.86s - 33.92s] Speaker speaker_0: तुम्हारे
# [33.98s - 34.24s] Speaker speaker_0: बिन
# [34.58s - 35.38s] Speaker speaker_0: मुझको
# [35.40s - 36.34s] Speaker speaker_0: जीना
# [36.40s - 37.16s] Speaker speaker_0: नहीं।
# [37.58s - 37.80s] Speaker speaker_0: हो
# [37.86s - 38.82s] Speaker speaker_0: मेरी
# [38.94s - 39.94s] Speaker speaker_0: जान
# [40.02s - 40.30s] Speaker speaker_0: तुम
# [40.60s - 41.62s] Speaker speaker_0: पापा।
# [42.00s - 42.64s] Speaker speaker_0: मेरे
# [42.74s - 44.30s] Speaker speaker_0: भगवान
# [44.42s - 44.70s] Speaker speaker_0: तुम
# [45.00s - 46.34s] Speaker speaker_0: पापा।
# [46.40s - 47.24s] Speaker speaker_0: (क्लोज़ की ध्वनि)
# [47.24s - 47.24s] Speaker speaker_0: (पृष्ठभूमि में संगीत बजता है)
# [47.24s - 47.84s] Speaker speaker_0: (पत्थर के घड़से से जूझ रहे हैं)
# [47.84s - 47.86s] Speaker speaker_0: (ध्वनि प्रभाव)
# [47.86s - 47.96s] Speaker speaker_0: अरे
# [47.96s - 49.72s] Speaker speaker_0: प्यारे
# [50.02s - 50.38s] Speaker speaker_0: अंकल
# [50.38s - 50.56s] Speaker speaker_0: आप
# [51.42s - 51.44s] Speaker speaker_0: मुझे
# [51.44s - 51.54s] Speaker speaker_0: कहां
# [51.54s - 51.54s] Speaker speaker_0: लेकर
# [51.54s - 51.62s] Speaker speaker_0: जा
# [51.62s - 51.86s] Speaker speaker_0: रहे
# [51.86s - 51.88s] Speaker speaker_0: हो?
# [51.88s - 51.88s] Speaker speaker_1: ओए
# [51.88s - 51.88s] Speaker speaker_1: तू
# [51.88s - 51.88s] Speaker speaker_1: चलता
# [51.88s - 51.88s] Speaker speaker_1: सही।
# [51.98s - 52.02s] Speaker speaker_1: एँठे
# [52.02s - 52.02s] Speaker speaker_1: खड़ा
# [52.02s - 52.02s] Speaker speaker_1: जा,
# [52.02s - 52.02s] Speaker speaker_1: एँठे
# [52.02s - 52.02s] Speaker speaker_1: खड़ा
# [52.02s - 52.02s] Speaker speaker_1: जा।
# [52.02s - 52.28s] Speaker speaker_1: उहहह
# [52.28s - 52.30s] Speaker speaker_1: हाँ
# [52.30s - 52.34s] Speaker speaker_1: उहदेख!
# [52.34s - 52.34s] Speaker speaker_1: (पृष्ठभूमि में संगीत बजता है)
# [52.34s - 52.34s] Speaker speaker_1: (हंसते हुए)
# [52.34s - 52.34s] Speaker speaker_0: थैंक
# [52.34s - 52.34s] Speaker speaker_0: यू
# [52.34s - 52.34s] Speaker speaker_0: पापा,
# [52.34s - 52.34s] Speaker speaker_0: थैंक
# [52.34s - 52.34s] Speaker speaker_0: यू
# [52.34s - 52.34s] Speaker speaker_0: सो
# [52.34s - 52.34s] Speaker speaker_0: मच।
# [52.34s - 52.34s] Speaker speaker_1: यू
# [52.34s - 52.34s] Speaker speaker_1: लाइक
# [52.34s - 52.34s] Speaker speaker_1: आईटी?
# [52.34s - 52.34s] Speaker speaker_0: या
# [52.34s - 52.34s] Speaker speaker_0: आई
# [52.34s - 52.34s] Speaker speaker_0: रियली
# [52.34s - 52.34s] Speaker speaker_0: लाइक
# [52.34s - 52.34s] Speaker speaker_0: आईटी।
# [52.34s - 52.34s] Speaker speaker_1: चलाएगा?
# [52.34s - 52.34s] Speaker speaker_0: हाँ
# [52.34s - 52.34s] Speaker speaker_0: पापा।
# [52.34s - 52.34s] Speaker speaker_1: समाज
# [52.34s - 52.34s] Speaker speaker_1: सिट।
# [52.34s - 52.34s] Speaker speaker_1: आह,
# [52.34s - 52.34s] Speaker speaker_1: रेडी?
# [52.34s - 52.34s] Speaker speaker_0: येस।
# [52.34s - 52.34s] Speaker speaker_1: ओके?
# [52.34s - 52.34s] Speaker speaker_0: ओके।
# [52.34s - 52.34s] Speaker speaker_1: कम
# [52.34s - 52.34s] Speaker speaker_1: ऑन,
# [52.34s - 52.34s] Speaker speaker_1: लेट्स
# [52.34s - 52.34s] Speaker speaker_1: गो।
# [52.34s - 52.34s] Speaker speaker_1: यस!
# [52.34s - 52.34s] Speaker speaker_1: हाँ
# [52.34s - 52.34s] Speaker speaker_1: कर्न्ट,
# [52.34s - 52.34s] Speaker speaker_1: कर्न्ट।
# [52.34s - 52.34s] Speaker speaker_1: शाबाश,
# [52.34s - 52.34s] Speaker speaker_1: शाबाश
# [52.34s - 52.34s] Speaker speaker_1: करण,
# [52.34s - 52.34s] Speaker speaker_1: शाबाश।
# [52.34s - 52.34s] Speaker speaker_1: हाँ,
# [52.34s - 52.34s] Speaker speaker_1: हाँ
# [52.34s - 52.34s] Speaker speaker_1: डरना
# [52.34s - 52.34s] Speaker speaker_1: मत,
# [52.34s - 52.34s] Speaker speaker_1: डर
# [52.34s - 52.34s] Speaker speaker_1: मा,
# [52.34s - 52.34s] Speaker speaker_1: डर
# [52.34s - 52.34s] Speaker speaker_1: मा।
# [52.34s - 52.34s] Speaker speaker_1: कम
# [52.34s - 52.34s] Speaker speaker_1: ऑन
# [52.34s - 52.34s] Speaker speaker_1: टर्न,
# [52.34s - 52.34s] Speaker speaker_1: टर्न,
# [52.34s - 52.34s] Speaker speaker_1: टर्न,
# [52.34s - 52.34s] Speaker speaker_1: टर्न।
# [52.34s - 52.34s] Speaker speaker_0: अब
# [52.34s - 52.34s] Speaker speaker_0: मैं
# [52.34s - 52.34s] Speaker speaker_0: चला
# [52.34s - 52.34s] Speaker speaker_0: लूंगा।
# [52.34s - 52.34s] Speaker speaker_1: प-प-पेता
# [52.34s - 52.34s] Speaker speaker_1: तू
# [52.34s - 52.34s] Speaker speaker_1: गिरेगा।
# [52.34s - 52.34s] Speaker speaker_0: पापा
# [52.34s - 52.34s] Speaker speaker_0: छोड़िए
# [52.34s - 52.34s] Speaker speaker_0: मैं
# [52.34s - 52.34s] Speaker speaker_0: खुद
# [52.34s - 52.34s] Speaker speaker_0: चला
# [52.34s - 52.34s] Speaker speaker_0: लूंगा।
# [52.34s - 52.34s] Speaker speaker_1: नहीं
# [52.34s - 52.34s] Speaker speaker_1: बेटा
# [52.34s - 52.34s] Speaker speaker_1: तू
# [52.34s - 52.34s] Speaker speaker_1: गिर
# [52.34s - 52.34s] Speaker speaker_1: जाएगा,
# [52.34s - 52.34s] Speaker speaker_1: संभाल
# [52.34s - 52.34s] Speaker speaker_1: के।
# [52.34s - 52.34s] Speaker speaker_0: पापा
# [52.34s - 52.34s] Speaker speaker_0: प्लीज
# [52.34s - 52.34s] Speaker speaker_0: छोड़िये।
# [52.34s - 52.34s] Speaker speaker_1: छोड़ूं
# [52.34s - 52.34s] Speaker speaker_1: मैं?
# [52.34s - 52.34s] Speaker speaker_0: हाँ
# [52.34s - 52.34s] Speaker speaker_0: प्लीज।
# [52.34s - 52.34s] Speaker speaker_1: ओके।
# [52.34s - 52.34s] Speaker speaker_1: संभाल
# [52.34s - 52.34s] Speaker speaker_1: के
# [52.34s - 52.34s] Speaker speaker_1: करण,
# [52.34s - 52.34s] Speaker speaker_1: संभाल
# [52.34s - 52.34s] Speaker speaker_1: के।
# [52.34s - 52.34s] Speaker speaker_1: अरे
# [52.34s - 52.34s] Speaker speaker_1: किसी
# [52.34s - 52.34s] Speaker speaker_1: को
# [52.34s - 52.34s] Speaker speaker_1: ठोक,
# [52.34s - 52.34s] Speaker speaker_1: ठोक
# [52.34s - 52.34s] Speaker speaker_1: मत
# [52.34s - 52.34s] Speaker speaker_1: करना।
# [52.34s - 52.34s] Speaker speaker_2: अरे
# [52.34s - 52.34s] Speaker speaker_2: वो
# [52.34s - 52.34s] Speaker speaker_2: साधा
# [52.34s - 52.34s] Speaker speaker_2: होता
# [52.34s - 52.34s] Speaker speaker_2: है
# [52.34s - 52.34s] Speaker speaker_2: संभाल
# [52.34s - 52.34s] Speaker speaker_2: के
# [52.34s - 52.34s] Speaker speaker_2: चला
# [52.34s - 52.34s] Speaker speaker_2: देगा,
# [52.34s - 52.34s] Speaker speaker_2: तू
# [52.34s - 52.34s] Speaker speaker_2: चिंता
# [52.34s - 52.34s] Speaker speaker_2: काहे
# [52.34s - 52.34s] Speaker speaker_2: को
# [52.34s - 52.34s] Speaker speaker_2: करता
# [52.34s - 52.34s] Speaker speaker_2: है?
# [52.34s - 52.34s] Speaker speaker_1: करण!
# [52.34s - 52.34s] Speaker speaker_2: चल
# [52.34s - 52.34s] Speaker speaker_2: चल,
# [52.34s - 52.34s] Speaker speaker_2: चल
# [52.34s - 52.34s] Speaker speaker_2: लस्सी
# [52.34s - 52.34s] Speaker speaker_2: पीते
# [52.34s - 52.34s] Speaker speaker_2: हैं।
# [52.34s - 52.34s] Speaker speaker_2: (खर्च की आवाज़)
# [52.34s - 52.34s] Speaker speaker_3: पॉपलेट
# [52.34s - 52.34s] Speaker speaker_3: वाली
# [52.34s - 52.34s] Speaker speaker_3: पॉपलेट,
# [52.34s - 52.34s] Speaker speaker_3: ताजा
# [52.34s - 52.34s] Speaker speaker_3: ताजा
# [52.34s - 52.34s] Speaker speaker_3: पॉपलेट।
# [52.34s - 52.34s] Speaker speaker_3: पॉपलेट।
# [52.34s - 52.34s] Speaker speaker_3: (दाऊल की आवाज़)
# [52.34s - 52.34s] Speaker speaker_3: मोटा
# [52.34s - 52.34s] Speaker speaker_3: मोटा
# [52.34s - 52.34s] Speaker speaker_3: ड्राई
# [52.34s - 52.34s] Speaker speaker_3: फ्रूट्स।
# [52.34s - 52.34s] Speaker speaker_3: (चिल्लाती हुई आवाज़)
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3: कुछ
# [52.34s - 52.34s] Speaker speaker_3: लेके
# [52.34s - 52.34s] Speaker speaker_3: आओ
# [52.34s - 52.34s] Speaker speaker_3: इस
# [52.34s - 52.34s] Speaker speaker_3: आदमी
# [52.34s - 52.34s] Speaker speaker_3: के।
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3: ब्रेक
# [52.34s - 52.34s] Speaker speaker_3: में
# [52.34s - 52.34s] Speaker speaker_3: नहीं
# [52.34s - 52.34s] Speaker speaker_3: सकता
# [52.34s - 52.34s] Speaker speaker_3: मैं
# [52.34s - 52.34s] Speaker speaker_3: ब्रेक
# [52.34s - 52.34s] Speaker speaker_3: तो।
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3: तू
# [52.34s - 52.34s] Speaker speaker_3: जी
# [52.34s - 52.34s] Speaker speaker_3: भाजी
# [52.34s - 52.34s] Speaker speaker_3: टंका।
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3: बाबा।
# [52.34s - 52.34s] Speaker speaker_1: डॉली!
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3: नीचे
# [52.34s - 52.34s] Speaker speaker_3: को
# [52.34s - 52.34s] Speaker speaker_3: देख,
# [52.34s - 52.34s] Speaker speaker_3: नीचे
# [52.34s - 52.34s] Speaker speaker_3: के
# [52.34s - 52.34s] Speaker speaker_3: पीछे
# [52.34s - 52.34s] Speaker speaker_3: को
# [52.34s - 52.34s] Speaker speaker_3: देख।
# [52.34s - 52.34s] Speaker speaker_3: ट्राट।
# [52.34s - 52.34s] Speaker speaker_3: आइगा!
# [52.34s - 52.34s] Speaker speaker_3: सत्यानाश
# [52.34s - 52.34s] Speaker speaker_3: हो
# [52.34s - 52.34s] Speaker speaker_3: तेरा
# [52.34s - 52.34s] Speaker speaker_3: हलकट।
# [52.34s - 52.34s] Speaker speaker_3: मेरा
# [52.34s - 52.34s] Speaker speaker_3: पूरा
# [52.34s - 52.34s] Speaker speaker_3: मच्छर
# [52.34s - 52.34s] Speaker speaker_3: गिरा
# [52.34s - 52.34s] Speaker speaker_3: है
# [52.34s - 52.34s] Speaker speaker_3: ना।
# [52.34s - 52.34s] Speaker speaker_3: छोडूंगी
# [52.34s - 52.34s] Speaker speaker_3: ना
# [52.34s - 52.34s] Speaker speaker_3: मैं
# [52.34s - 52.34s] Speaker speaker_3: तेरे
# [52.34s - 52.34s] Speaker speaker_3: को।
# [52.34s - 52.34s] Speaker speaker_3: हलकट
# [52.34s - 52.34s] Speaker speaker_3: कहां
# [52.34s - 52.34s] Speaker speaker_3: से
# [52.34s - 52.34s] Speaker speaker_3: गिरा?
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3: घोड़-घोड़े
# [52.34s - 52.34s] Speaker speaker_3: से
# [52.34s - 52.34s] Speaker speaker_3: धारा
# [52.34s - 52.34s] Speaker speaker_3: पकड़
# [52.34s - 52.34s] Speaker speaker_3: ला।
# [52.34s - 52.34s] Speaker speaker_3: (स्टीयरिंग के चाके गिरने की आवाज आती है)
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3: थाप!
# [52.34s - 52.34s] Speaker speaker_1: अरे
# [52.34s - 52.34s] Speaker speaker_1: डॉली
# [52.34s - 52.34s] Speaker speaker_1: खाओ
# [52.34s - 52.34s] Speaker speaker_1: नारे,
# [52.34s - 52.34s] Speaker speaker_1: नारे।
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3: घोड़े
# [52.34s - 52.34s] Speaker speaker_3: से
# [52.34s - 52.34s] Speaker speaker_3: कहां
# [52.34s - 52.34s] Speaker speaker_3: से
# [52.34s - 52.34s] Speaker speaker_3: गिरे?
# [52.34s - 52.34s] Speaker speaker_3: (लोग चिल्लाते हुए)
# [52.34s - 52.34s] Speaker speaker_1: सॉरी
# [52.34s - 52.34s] Speaker speaker_1: डॉली।
# [52.34s - 52.34s] Speaker speaker_3: तेरे
# [52.34s - 52.34s] Speaker speaker_3: को।
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3: ठेकेदार
# [52.34s - 52.34s] Speaker speaker_3: थाप!
# [52.34s - 52.34s] Speaker speaker_3: (हीट से गीली छवि किरण आ जाने की आवाज आती है)
# [52.34s - 52.34s] Speaker speaker_3: आइला
# [52.34s - 52.34s] Speaker speaker_3: सॉरी
# [52.34s - 52.34s] Speaker speaker_3: अंकल।
# [52.34s - 52.34s] Speaker speaker_1: (हंसते हुए)
# [52.34s - 52.34s] Speaker speaker_1: इधर
# [52.34s - 52.34s] Speaker speaker_1: से
# [52.34s - 52.34s] Speaker speaker_1: गिर
# [52.34s - 52.34s] Speaker speaker_1: जाए,
# [52.34s - 52.34s] Speaker speaker_1: उधर
# [52.34s - 52.34s] Speaker speaker_1: से
# [52.34s - 52.34s] Speaker speaker_1: गिर
# [52.34s - 52.34s] Speaker speaker_1: जाए।
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3: ढींगे!
# [52.34s - 52.34s] Speaker speaker_3: हाँ,
# [52.34s - 52.34s] Speaker speaker_3: हाँ।
# [52.34s - 52.34s] Speaker speaker_3: (लात मारने की आवाज आती है)
# [52.34s - 52.34s] Speaker speaker_3: अभी
# [52.34s - 52.34s] Speaker speaker_3: तू
# [52.34s - 52.34s] Speaker speaker_3: बच
# [52.34s - 52.34s] Speaker speaker_3: के
# [52.34s - 52.34s] Speaker speaker_3: कहां
# [52.34s - 52.34s] Speaker speaker_3: जाएगा?
# [52.34s - 52.34s] Speaker speaker_3: हाँ,
# [52.34s - 52.34s] Speaker speaker_3: क्यों
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3: ढींगे?
# [52.34s - 52.34s] Speaker speaker_3: अब
# [52.34s - 52.34s] Speaker speaker_3: तू
# [52.34s - 52.34s] Speaker speaker_3: आया
# [52.34s - 52.34s] Speaker speaker_3: ना
# [52.34s - 52.34s] Speaker speaker_3: मेरे
# [52.34s - 52.34s] Speaker speaker_3: नेट
# [52.34s - 52.34s] Speaker speaker_3: में।
# [52.34s - 52.34s] Speaker speaker_3: अब
# [52.34s - 52.34s] Speaker speaker_3: देख
# [52.34s - 52.34s] Speaker speaker_3: मैं
# [52.34s - 52.34s] Speaker speaker_3: कैसे
# [52.34s - 52.34s] Speaker speaker_3: तेरा
# [52.34s - 52.34s] Speaker speaker_3: छील
# [52.34s - 52.34s] Speaker speaker_3: कर
# [52.34s - 52.34s] Speaker speaker_3: निकलती
# [52.34s - 52.34s] Speaker speaker_3: है।
# [52.34s - 52.34s] Speaker speaker_0: माफ
# [52.34s - 52.34s] Speaker speaker_0: करना
# [52.34s - 52.34s] Speaker speaker_0: गलती
# [52.34s - 52.34s] Speaker speaker_0: हो
# [52.34s - 52.34s] Speaker speaker_0: गई
# [52.34s - 52.34s] Speaker speaker_0: मौसी।
# [52.34s - 52.34s] Speaker speaker_3: मौसी!
# [52.34s - 52.34s] Speaker speaker_3: उन्नीस
# [52.34s - 52.34s] Speaker speaker_3: साल
# [52.34s - 52.34s] Speaker speaker_3: की
# [52.34s - 52.34s] Speaker speaker_3: लड़की
# [52.34s - 52.34s] Speaker speaker_3: को
# [52.34s - 52.34s] Speaker speaker_3: मौसी
# [52.34s - 52.34s] Speaker speaker_3: बुलाता
# [52.34s - 52.34s] Speaker speaker_3: है।
# [52.34s - 52.34s] Speaker speaker_3: मैं
# [52.34s - 52.34s] Speaker speaker_3: तेरी
# [52.34s - 52.34s] Speaker speaker_3: मां
# [52.34s - 52.34s] Speaker speaker_3: की
# [52.34s - 52.34s] Speaker speaker_3: बहन
# [52.34s - 52.34s] Speaker speaker_3: लगती
# [52.34s - 52.34s] Speaker speaker_3: है
# [52.34s - 52.34s] Speaker speaker_3: क्या?
# [52.34s - 52.34s] Speaker speaker_3: तेरे
# [52.34s - 52.34s] Speaker speaker_3: को
# [52.34s - 52.34s] Speaker speaker_3: तान्हा।
# [52.34s - 52.34s] Speaker speaker_0: हवलदार!
# [52.34s - 52.34s] Speaker speaker_3: किधर
# [52.34s - 52.34s] Speaker speaker_3: है?
# [52.34s - 52.34s] Speaker speaker_3: हवलदार
# [52.34s - 52.34s] Speaker speaker_3: किधर
# [52.34s - 52.34s] Speaker speaker_3: है?
# [52.34s - 52.34s] Speaker speaker_3: हाँ,
# [52.34s - 52.34s] Speaker speaker_3: बता
# [52.34s - 52.34s] Speaker speaker_3: देवर
# [52.34s - 52.34s] Speaker speaker_3: को
# [52.34s - 52.34s] Speaker speaker_3: भी
# [52.34s - 52.34s] Speaker speaker_3: तुमने
# [52.34s - 52.34s] Speaker speaker_3: कुछ
# [52.34s - 52.34s] Speaker speaker_3: भी
# [52.34s - 52.34s] Speaker speaker_3: किया,
# [52.34s - 52.34s] Speaker speaker_3: मैं
# [52.34s - 52.34s] Speaker speaker_3: उसे
# [52.34s - 52.34s] Speaker speaker_3: छोडूंगी
# [52.34s - 52.34s] Speaker speaker_3: नहीं।
# [52.34s - 52.34s] Speaker speaker_3: (लात मारने की आवाज आती है)
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3: जगा,
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3: वो
# [52.34s - 52.34s] Speaker speaker_3: आंको
# [52.34s - 52.34s] Speaker speaker_3: ना
# [52.34s - 52.34s] Speaker speaker_3: वो,
# [52.34s - 52.34s] Speaker speaker_3: वो
# [52.34s - 52.34s] Speaker speaker_3: आंको।
# [52.34s - 52.34s] Speaker speaker_3: (लात मारने की आवाज आती है)
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3: तेरे
# [52.34s - 52.34s] Speaker speaker_3: को
# [52.34s - 52.34s] Speaker speaker_3: मैं
# [52.34s - 52.34s] Speaker speaker_3: छोडूंगी
# [52.34s - 52.34s] Speaker speaker_3: नहीं।
# [52.34s - 52.34s] Speaker speaker_1: संभाल।
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3: गवाया,
# [52.34s - 52.34s] Speaker speaker_3: अरे
# [52.34s - 52.34s] Speaker speaker_3: गोली
# [52.34s - 52.34s] Speaker speaker_3: तेरी
# [52.34s - 52.34s] Speaker speaker_3: मार
# [52.34s - 52.34s] Speaker speaker_3: दूं।
# [52.34s - 52.34s] Speaker speaker_1: एक
# [52.34s - 52.34s] Speaker speaker_1: मिनट,
# [52.34s - 52.34s] Speaker speaker_1: एक
# [52.34s - 52.34s] Speaker speaker_1: मिनट,
# [52.34s - 52.34s] Speaker speaker_1: एक
# [52.34s - 52.34s] Speaker speaker_1: मिनट।
# [52.34s - 52.34s] Speaker speaker_1: अरे,
# [52.34s - 52.34s] Speaker speaker_1: अरे
# [52.34s - 52.34s] Speaker speaker_1: देखिए,
# [52.34s - 52.34s] Speaker speaker_1: देखिए
# [52.34s - 52.34s] Speaker speaker_1: मेरी
# [52.34s - 52.34s] Speaker speaker_1: बात
# [52.34s - 52.34s] Speaker speaker_1: सुनिए।
# [52.34s - 52.34s] Speaker speaker_1: (लड़की चिल्लाती हुई)
# [52.34s - 52.34s] Speaker speaker_1: अरे
# [52.34s - 52.34s] Speaker speaker_1: ए,
# [52.34s - 52.34s] Speaker speaker_1: हाथ
# [52.34s - 52.34s] Speaker speaker_1: दबाई
# [52.34s - 52.34s] Speaker speaker_1: क्यों
# [52.34s - 52.34s] Speaker speaker_1: रही
# [52.34s - 52.34s] Speaker speaker_1: हो?
# [52.34s - 52.34s] Speaker speaker_1: (लड़की चिल्लाती हुई)
# [52.34s - 52.34s] Speaker speaker_1: अरे
# [52.34s - 52.34s] Speaker speaker_1: भाग
# [52.34s - 52.34s] Speaker speaker_1: क्यों
# [52.34s - 52.34s] Speaker speaker_1: रही
# [52.34s - 52.34s] Speaker speaker_1: हो?
# [52.34s - 52.68s] Speaker speaker_1: (लड़की चिल्लाती हुई)
# [52.68s - 52.68s] Speaker speaker_1: अरे,
# [52.68s - 52.68s] Speaker speaker_1: अरे
# [52.68s - 52.68s] Speaker speaker_1: रुको,
# [52.68s - 52.68s] Speaker speaker_1: रुको,
# [52.68s - 52.68s] Speaker speaker_1: रुको।
# [52.68s - 52.68s] Speaker speaker_1: मैं
# [52.68s - 52.68s] Speaker speaker_1: तुम्हारी
# [52.68s - 52.70s] Speaker speaker_1: मदद
# [52.70s - 52.72s] Speaker speaker_1: करने
# [53.16s - 53.18s] Speaker speaker_1: की
# [53.18s - 53.18s] Speaker speaker_1: कोशिश
# [53.18s - 53.18s] Speaker speaker_1: कर
# [53.18s - 53.18s] Speaker speaker_1: रहा
# [53.18s - 53.18s] Speaker speaker_1: हूं।
# [53.18s - 53.18s] Speaker speaker_3: अरे
# [53.18s - 53.18s] Speaker speaker_3: जल्दी
# [53.18s - 85.16s] Speaker speaker_3: निकलो
# [101.54s - 176.26s] Speaker speaker_3: मेरे
# [176.26s - 176.46s] Speaker speaker_3: को
# [176.76s - 186.84s] Speaker speaker_3: सांस
# [203.78s - 254.06s] Speaker speaker_3: नहीं
# [254.20s - 254.36s] Speaker speaker_3: रहा
# [254.36s - 255.04s] Speaker speaker_3: है।
# [255.04s - 255.20s] Speaker speaker_1: अरे
# [255.42s - 255.66s] Speaker speaker_1: जाएगी
# [255.66s - 255.82s] Speaker speaker_1: तुम
# [255.82s - 256.06s] Speaker speaker_1: सीधी
# [256.08s - 256.28s] Speaker speaker_1: खड़ी
# [256.28s - 256.72s] Speaker speaker_1: रहो।
# [256.74s - 256.94s] Speaker speaker_1: एक
# [256.96s - 257.32s] Speaker speaker_1: मिनट।
# [257.32s - 259.56s] Speaker speaker_3: (लड़की सांस लेती हुए)
# [259.56s - 259.72s] Speaker speaker_3: अरे
# [259.74s - 260.14s] Speaker speaker_3: अटक
# [260.14s - 261.84s] Speaker speaker_3: गया।
# [261.84s - 262.46s] Speaker speaker_3: अरे
# [262.48s - 262.84s] Speaker speaker_3: जल्दी
# [262.86s - 263.18s] Speaker speaker_3: निकल
# [263.18s - 263.80s] Speaker speaker_3: दो।
# [263.80s - 264.74s] Speaker speaker_1: अरे
# [264.74s - 264.86s] Speaker speaker_1: ये
# [264.86s - 265.12s] Speaker speaker_1: हैंडा
# [265.14s - 265.44s] Speaker speaker_1: अटक
# [265.44s - 265.70s] Speaker speaker_1: कैसे
# [265.70s - 265.98s] Speaker speaker_1: गया?
# [268.08s - 268.36s] Speaker speaker_1: (किसी चीज को तोड़ते हुए)
# [268.36s - 268.52s] Speaker speaker_1: आह,
# [269.22s - 272.14s] Speaker speaker_1: आह।
# [272.14s - 273.40s] Speaker speaker_3: (लड़की सांस लेती है)
# [273.40s - 273.42s] Speaker speaker_3: हा,
# [273.52s - 273.92s] Speaker speaker_3: हा।
# [273.92s - 273.94s] Speaker speaker_4: (गाना गाया जाता है)
# [274.98s - 275.00s] Speaker speaker_4: ही
# [275.02s - 275.22s] Speaker speaker_4: ही
# [275.22s - 275.24s] Speaker speaker_4: ही
# [275.24s - 275.24s] Speaker speaker_4: ही
# [275.24s - 275.24s] Speaker speaker_4: ही
# [275.24s - 275.24s] Speaker speaker_4: ही
# [275.40s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4: ही
# [275.42s - 275.42s] Speaker speaker_4: ही
# [276.60s - 276.84s] Speaker speaker_4: ही।
# [276.88s - 277.32s] Speaker speaker_4: लागा
# [277.36s - 277.88s] Speaker speaker_4: लगा
# [277.88s - 277.98s] Speaker speaker_4: के
# [277.98s - 278.00s] Speaker speaker_4: इंकार,
# [278.00s - 278.00s] Speaker speaker_4: पानी
# [278.00s - 278.00s] Speaker speaker_4: की
# [278.04s - 283.72s] Speaker speaker_4: बट्टी
# [283.72s - 283.74s] Speaker speaker_4: में
# [283.74s - 285.46s] Speaker speaker_4: गया।
# [285.50s - 285.90s] Speaker speaker_4: लागा
# [286.14s - 286.30s] Speaker speaker_4: लगा
# [286.34s - 286.46s] Speaker speaker_4: के
# [286.74s - 287.26s] Speaker speaker_4: इंकार,
# [287.72s - 288.08s] Speaker speaker_4: पानी
# [288.20s - 288.34s] Speaker speaker_4: की
# [288.54s - 288.66s] Speaker speaker_4: बट्टी
# [288.70s - 289.28s] Speaker speaker_4: में
# [289.48s - 289.50s] Speaker speaker_4: गया।
# [289.50s - 296.18s] Speaker speaker_4: (बैकग्राउंड में संगीत बजता है)
# [296.18s - 297.58s] Speaker speaker_1: सॉरी।
# [297.58s - 297.90s] Speaker speaker_0: माफी
# [297.90s - 298.00s] Speaker speaker_0: काहे
# [298.02s - 298.08s] Speaker speaker_0: को
# [298.10s - 298.44s] Speaker speaker_0: मांगता
# [298.44s - 298.62s] Speaker speaker_0: है?
# [299.32s - 299.68s] Speaker speaker_0: अच्छा
# [299.74s - 299.92s] Speaker speaker_0: लगा
# [299.94s - 299.98s] Speaker speaker_0: मिल
# [299.98s - 299.98s] Speaker speaker_0: तो।

# %%
import requests

API_KEY = ""  # or set via environment variable ELEVENLABS_API_KEY
AUDIO_PATH = "/home/csc/Documents/Multilingual-Transcriber/shared_data/movieslist/rishtey/audio_files/rishtey_part6__audio.mp3"  # support WAV, MP3, etc.

url = "https://api.elevenlabs.io/v1/speech-to-text"

headers = {
    "xi-api-key": API_KEY
}

with open(AUDIO_PATH, "rb") as f:
    files = {"file": f}
    data = {
        "model_id": "scribe_v1",
        "diarize": True
    }
    response = requests.post(url, headers=headers, data=data, files=files)

result = response.json()

print("\nFull Transcript:\n", result.get("text", ""))

# Group by speaker
if "words" in result:
    grouped_transcript = []
    current_speaker = None
    current_text = []
    start_time = None

    for w in result["words"]:
        speaker = w.get("speaker", w.get("speaker_id", "Unknown"))
        word_text = w.get("text", "")
        word_start = w.get("start", 0)
        word_end = w.get("end", 0)

        if current_speaker is None:
            # First word
            current_speaker = speaker
            current_text = [word_text]
            start_time = word_start
            end_time = word_end
        elif speaker == current_speaker:
            # Same speaker, keep adding words
            current_text.append(word_text)
            end_time = word_end
        else:
            # Speaker changed, save previous
            grouped_transcript.append({
                "speaker": current_speaker,
                "start": start_time,
                "end": end_time,
                "text": " ".join(current_text)
            })
            # Start new speaker group
            current_speaker = speaker
            current_text = [word_text]
            start_time = word_start
            end_time = word_end

    # Save the last group
    if current_text:
        grouped_transcript.append({
            "speaker": current_speaker,
            "start": start_time,
            "end": end_time,
            "text": " ".join(current_text)
        })

    # Print nicely
    print("\nDiarized Transcript (Grouped):\n")
    for segment in grouped_transcript:
        print(f"Speaker {segment['speaker']} ({segment['start']:.2f}s - {segment['end']:.2f}s): {segment['text']}")
# Out:
# Full Transcript:
#  , टरी को। (एलईडी ध्वनि) अअअ! (चिल्लाते हुए) क्या हुआ? मुंबई इलेक्ट्रिसिटी बोर्ड में काम करता है क्या? मुंबई इलेक्ट्रिसिटी बोर्ड? टच किया तो आपका बॉडी में झनझना कर एक करंट लगा। अच्छा? हो। पापा। तेरे पापा की तो धाबा... (एलईडी ध्वनि) ये... तेरे को पापा बोला? हां, मुझे पापा बोला। तेरा पोरगा ये? पोरगा? अरे, तेरा बेटा है ये? हां, मेरा बेटा है। देवा... देवा... देवा... देवा... (रोते हुए) मैं बर्बाद हो गई देवा... देवा... देवा... अरे! क्या बस! काहे को इतना रोती है? अरे, काहे सांगू मामा? ऊँ! ये आंसू मेरे दिल की जुबान है। मेरा हंसना कोई घराना बहकाने... अरे ले आराम... अरे दिगंबर! हाँँह! कौन है ये लड़की? काहे रोए जा रही है? अरे, मेरी भांजी है वैजयंती। कलीज़ अलीबाग से आई है। दिल नहीं साथ में कलिंगड़ लाई है। ना जाने किस से टकराई है। आज ते ही सारा मोहल्ला सर पर उठाई है। देवा... देवा... देवा... अच्छा, अच्छा, अच्छा। तू ठहर मैं पूछती हूं। हाँ, पूछो। हमको बता, क्या हुआ? हाँँ? अरे, काहे सांगू काकी? मेरी लव स्टोरी शुरू होने से पहले ही थी एंड हो गई। दोपहर की घड़ी थी। हम दोनों की आंख लड़ी थी। आंखों आंखों में एक्शन हुआ। दिल से दिल का कनेक्शन हुआ। इतने में आवाज आई पापा... सात साल का बच्चा है उसका। (रोते हुए) देवा... अब ये दुनिया, ये महफिल मेरे काम की नहीं। वैजयंती की जवानी कोई दाम की नहीं है। (रोते हुए) अरे पगली, जिससे तू टकराई थी ना, उसकी औरत अब इस दुनिया में नहीं है। क्या? तेरे को कैसे मालूम काकी? अरे, वो काम अच्छी तरह जानत है। बड़ा भला मानस है वो। सुन, आज शरद पूर्णिमा की रात है। पूरी बस्ती जमा होगी यहाँ। हाँ। वो भी आने वाला है। तू भी चली आना। हाँ, मैं चलती हूँ (हंसते हुए)। आइला... फिर तो मैं उतारे कर डालेंगे वन, टू का फोर। अगर ना नाचा वो मोर। तू खिला देना एक गोली। फिर देखना इस गोली का जोर। ये काहे की गोली है मामा? चुम्मा गोली। जिसको एक गोली खिलाएगी, सब चुम्मा लेगा। (लपेटते हुए) हैं! आई शापित। हाँँह! ये एक गोली में सौ चुम्मा? हाँँह! पूरी बोतल खिला दें तो? पूरा सत्यानाश हो जाएगा। (लोग हंसते हुए) (मुस्कुराने की आवाज़) ये... ये... ये... (लोग दौड़ते हुए) क्यू ऑन ला! देख ना मामा। कैसे कंगारू के भांपी 24 घंटे बच्चे को चिपकाकर बैठे रखा है। अब मैं अपना सेटिंग कैसे करेगी? अरे, तू फिक्र मत करा। मैं है ना। अभी व्यवस्था करता हूं। इयाया... (लोग लात मारते हुए) चलो बच्चे लोग, आज मामा तुमको झूला झुलाएगा वो भी फुकट में। (चिल्लाते हुए) याया...! चलो ओ बच्चे लोग, इयाया...! मैं इन बच्चों को लेकर जाता हूं झूले पर। तू सूरज को चढ़ा दे चूल्हे पर। आइला मामी... ग्र्रन... गरन... डक डक आ... (भाईले खेलते हुए) (बैकग्राउंड में पृष्ठभूमि संगीत बजता है) अअअ! (चम्मच से चट की आवाज आती है) अ... उह... गोली खाएगा क्या? गोली? बंदूक की गोली नहीं, ठंडक की गोली। खाने के बाद अच्छा लगता है। दूं क्या? अब तुम... (हंसते हुए) अब तुम इतनी तारीफ कर रही हो तो खा लूंगा। हँ! आइला... वो शरबत में डाल के देना पड़ता है। वो मैं पीली के आती हूँ, दाना मत। अह्... अह्... आह! थैंक यू देवा, थैंक यू। सूप... अब मामा के गोली का कमाल देखती है मैं। अब शरबत कहां मिलेगा? ए शरबत! हम्म! (घबराते हुए) ए शरबत, रुक। हम्म! अरे, ये कहां जा रहा है? अरे सूरज, सूरज, सूरज! कहां तू जाता है? मैं तेरे पास शरबत बनाकर लेके आई है। इतनी देर बाद अभी शरबत पीने का मूड नहीं है, वैजयंती। ऐसा कैसा? इतने प्यार से बनाकर लेके आई है। पीना ही पड़ेगा। (हंसते हुए) ये शरबत में उबाल कैसा? तू पिएगा, तेरे अंदर भी उबाल आएगा। हाँँ? हां, बहुत अच्छा है। पी पी, पी के देखो। सच्ची, सच्ची। (हंसते हुए) हां... (ध्यान से खपेटते हुए) आह, से लगा? (लाखों चिर-चिराते हुए) ऑऑऑऑ... (लाखों आवाज आती है) लगता है, गोली का असर हो रहा है। मेरी तरफ देख रहा है। हुंह? अ, हूं, मेरी तरफ आ रहा है, देवा। लगता है मेरी मछमूरत पूरी होगी।
#
# Diarized Transcript (Grouped):
#
# Speaker speaker_0 (0.00s - 6.76s): ,   टरी   को।   (एलईडी ध्वनि)   अअअ!   (चिल्लाते हुए)   क्या   हुआ?
# Speaker speaker_1 (6.76s - 9.34s): मुंबई   इलेक्ट्रिसिटी   बोर्ड   में   काम   करता   है   क्या?
# Speaker speaker_0 (9.34s - 11.80s): मुंबई   इलेक्ट्रिसिटी   बोर्ड?
# Speaker speaker_1 (11.80s - 15.14s): टच   किया   तो   आपका   बॉडी   में   झनझना   कर   एक   करंट   लगा।
# Speaker speaker_0 (15.14s - 16.58s): अच्छा?   हो।
# Speaker speaker_1 (16.58s - 19.38s): पापा।
# Speaker speaker_0 (19.38s - 28.82s): तेरे   पापा   की   तो   धाबा...   (एलईडी ध्वनि)
# Speaker speaker_1 (28.82s - 30.56s): ये...   तेरे   को   पापा   बोला?
# Speaker speaker_0 (30.56s - 32.16s): हां,   मुझे   पापा   बोला।
# Speaker speaker_1 (32.16s - 33.26s): तेरा   पोरगा   ये?
# Speaker speaker_0 (33.26s - 34.64s): पोरगा?
# Speaker speaker_1 (34.64s - 36.40s): अरे,   तेरा   बेटा   है   ये?
# Speaker speaker_0 (36.40s - 38.38s): हां,   मेरा   बेटा   है।
# Speaker speaker_1 (38.38s - 50.60s): देवा...   देवा...   देवा...   देवा...   (रोते हुए)   मैं   बर्बाद   हो   गई   देवा...   देवा...   देवा...
# Speaker speaker_0 (50.60s - 53.54s): अरे!   क्या   बस!   काहे   को   इतना   रोती   है?
# Speaker speaker_1 (53.54s - 55.16s): अरे,   काहे   सांगू   मामा?
# Speaker speaker_0 (55.16s - 55.44s): ऊँ!
# Speaker speaker_1 (55.44s - 60.18s): ये   आंसू   मेरे   दिल   की   जुबान   है।   मेरा   हंसना   कोई   घराना   बहकाने...
# Speaker speaker_0 (60.18s - 60.66s): अरे   ले   आराम...
# Speaker speaker_2 (60.66s - 61.50s): अरे   दिगंबर!
# Speaker speaker_0 (61.50s - 61.82s): हाँँह!
# Speaker speaker_2 (61.82s - 63.60s): कौन   है   ये   लड़की?   काहे   रोए   जा   रही   है?
# Speaker speaker_3 (63.60s - 74.82s): अरे,   मेरी   भांजी   है   वैजयंती।   कलीज़   अलीबाग   से   आई   है।   दिल   नहीं   साथ   में   कलिंगड़   लाई   है।   ना   जाने   किस   से   टकराई   है।   आज   ते   ही   सारा   मोहल्ला   सर   पर   उठाई   है।   देवा...   देवा...   देवा...
# Speaker speaker_2 (74.82s - 76.64s): अच्छा,   अच्छा,   अच्छा।   तू   ठहर   मैं   पूछती   हूं।
# Speaker speaker_3 (76.64s - 77.64s): हाँ,   पूछो।
# Speaker speaker_2 (77.64s - 79.90s): हमको   बता,   क्या   हुआ?   हाँँ?
# Speaker speaker_1 (79.90s - 109.02s): अरे,   काहे   सांगू   काकी?   मेरी   लव   स्टोरी   शुरू   होने   से   पहले   ही   थी   एंड   हो   गई।   दोपहर   की   घड़ी   थी।   हम   दोनों   की   आंख   लड़ी   थी।   आंखों   आंखों   में   एक्शन   हुआ।   दिल   से   दिल   का   कनेक्शन   हुआ।   इतने   में   आवाज   आई   पापा...   सात   साल   का   बच्चा   है   उसका।   (रोते हुए)   देवा...   अब   ये   दुनिया,   ये   महफिल   मेरे   काम   की   नहीं।   वैजयंती   की   जवानी   कोई   दाम   की   नहीं   है।   (रोते हुए)
# Speaker speaker_2 (109.02s - 114.36s): अरे   पगली,   जिससे   तू   टकराई   थी   ना,   उसकी   औरत   अब   इस   दुनिया   में   नहीं   है।
# Speaker speaker_1 (114.36s - 117.24s): क्या?   तेरे   को   कैसे   मालूम   काकी?
# Speaker speaker_2 (117.24s - 125.48s): अरे,   वो   काम   अच्छी   तरह   जानत   है।   बड़ा   भला   मानस   है   वो।   सुन,   आज   शरद   पूर्णिमा   की   रात   है।   पूरी   बस्ती   जमा   होगी   यहाँ।
# Speaker speaker_0 (125.48s - 126.28s): हाँ।
# Speaker speaker_2 (126.28s - 131.42s): वो   भी   आने   वाला   है।   तू   भी   चली   आना।   हाँ,   मैं   चलती   हूँ   (हंसते हुए) ।
# Speaker speaker_1 (131.42s - 135.20s): आइला...   फिर   तो   मैं   उतारे   कर   डालेंगे   वन,   टू   का   फोर।
# Speaker speaker_0 (135.20s - 140.04s): अगर   ना   नाचा   वो   मोर।   तू   खिला   देना   एक   गोली।   फिर   देखना   इस   गोली   का   जोर।
# Speaker speaker_1 (140.04s - 141.48s): ये   काहे   की   गोली   है   मामा?
# Speaker speaker_0 (141.48s - 146.10s): चुम्मा   गोली।   जिसको   एक   गोली   खिलाएगी,   सब   चुम्मा   लेगा।   (लपेटते हुए)
# Speaker speaker_1 (146.10s - 146.94s): हैं!   आई   शापित।
# Speaker speaker_0 (146.94s - 147.50s): हाँँह!
# Speaker speaker_1 (147.50s - 149.26s): ये   एक   गोली   में   सौ   चुम्मा?
# Speaker speaker_0 (149.26s - 149.70s): हाँँह!
# Speaker speaker_1 (149.70s - 151.30s): पूरी   बोतल   खिला   दें   तो?
# Speaker speaker_0 (151.30s - 160.40s): पूरा   सत्यानाश   हो   जाएगा।   (लोग हंसते हुए)   (मुस्कुराने की आवाज़)
# Speaker speaker_1 (160.40s - 171.04s): ये...   ये...   ये...   (लोग दौड़ते हुए)   क्यू   ऑन   ला!   देख   ना   मामा।   कैसे   कंगारू   के   भांपी   24   घंटे   बच्चे   को   चिपकाकर   बैठे   रखा   है।   अब   मैं   अपना   सेटिंग   कैसे   करेगी?
# Speaker speaker_0 (171.04s - 189.68s): अरे,   तू   फिक्र   मत   करा।   मैं   है   ना।   अभी   व्यवस्था   करता   हूं।   इयाया...   (लोग लात मारते हुए)   चलो   बच्चे   लोग,   आज   मामा   तुमको   झूला   झुलाएगा   वो   भी   फुकट   में।   (चिल्लाते हुए)   याया...!   चलो   ओ   बच्चे   लोग,   इयाया...!   मैं   इन   बच्चों   को   लेकर   जाता   हूं   झूले   पर।   तू   सूरज   को   चढ़ा   दे   चूल्हे   पर।
# Speaker speaker_1 (189.68s - 190.64s): आइला   मामी...
# Speaker speaker_0 (190.64s - 203.44s): ग्र्रन...   गरन...   डक   डक   आ...   (भाईले खेलते हुए)   (बैकग्राउंड में पृष्ठभूमि संगीत बजता है)
# Speaker speaker_1 (203.44s - 205.34s): अअअ!   (चम्मच से चट की आवाज आती है)   अ...   उह...   गोली   खाएगा   क्या?
# Speaker speaker_0 (205.34s - 206.04s): गोली?
# Speaker speaker_1 (206.04s - 213.18s): बंदूक   की   गोली   नहीं,   ठंडक   की   गोली।   खाने   के   बाद   अच्छा   लगता   है।   दूं   क्या?
# Speaker speaker_0 (213.18s - 216.64s): अब   तुम...   (हंसते हुए)   अब   तुम   इतनी   तारीफ   कर   रही   हो   तो   खा   लूंगा।
# Speaker speaker_1 (216.64s - 222.36s): हँ!   आइला...   वो   शरबत   में   डाल   के   देना   पड़ता   है।   वो   मैं   पीली   के   आती   हूँ,   दाना   मत।
# Speaker speaker_0 (222.36s - 223.62s): अह्...   अह्...
# Speaker speaker_1 (223.62s - 231.72s): आह!   थैंक   यू   देवा,   थैंक   यू।   सूप...   अब   मामा   के   गोली   का   कमाल   देखती   है   मैं।   अब   शरबत   कहां   मिलेगा?   ए   शरबत!
# Speaker speaker_4 (231.72s - 231.96s): हम्म!   (घबराते हुए)
# Speaker speaker_1 (231.96s - 232.46s): ए   शरबत,   रुक।
# Speaker speaker_0 (232.46s - 235.98s): हम्म!
# Speaker speaker_1 (235.98s - 243.62s): अरे,   ये   कहां   जा   रहा   है?   अरे   सूरज,   सूरज,   सूरज!   कहां   तू   जाता   है?   मैं   तेरे   पास   शरबत   बनाकर   लेके   आई   है।
# Speaker speaker_0 (243.62s - 245.70s): इतनी   देर   बाद   अभी   शरबत   पीने   का   मूड   नहीं   है,   वैजयंती।
# Speaker speaker_1 (245.70s - 250.86s): ऐसा   कैसा?   इतने   प्यार   से   बनाकर   लेके   आई   है।   पीना   ही   पड़ेगा।   (हंसते हुए)
# Speaker speaker_0 (250.86s - 252.26s): ये   शरबत   में   उबाल   कैसा?
# Speaker speaker_1 (252.26s - 253.78s): तू   पिएगा,   तेरे   अंदर   भी   उबाल   आएगा।
# Speaker speaker_0 (253.78s - 254.06s): हाँँ?
# Speaker speaker_1 (254.06s - 257.58s): हां,   बहुत   अच्छा   है।   पी   पी,   पी   के   देखो।   सच्ची,   सच्ची।   (हंसते हुए)
# Speaker speaker_0 (257.58s - 264.16s): हां...   (ध्यान से खपेटते हुए)
# Speaker speaker_1 (264.16s - 264.60s): आह,   से   लगा?
# Speaker speaker_4 (264.60s - 278.98s): (लाखों चिर-चिराते हुए)
# Speaker speaker_1 (278.98s - 299.98s): ऑऑऑऑ...   (लाखों आवाज आती है)   लगता   है,   गोली   का   असर   हो   रहा   है।   मेरी   तरफ   देख   रहा   है।   हुंह?   अ,   हूं,   मेरी   तरफ   आ   रहा   है,   देवा।   लगता   है   मेरी   मछमूरत   पूरी   होगी।

# %%
import requests

import requests

API_KEY = ""  # or set via environment variable ELEVENLABS_API_KEY
AUDIO_PATH = "/home/csc/Documents/Multilingual-Transcriber/shared_data/movieslist/rishtey/audio_files/rishtey_part5__audio.mp3"  # support WAV, MP3, etc.

url = "https://api.elevenlabs.io/v1/speech-to-text"

headers = {
    "xi-api-key": API_KEY
}

with open(AUDIO_PATH, "rb") as f:
    files = {"file": f}
    data = {
        "model_id": "scribe_v1",
        "diarize": True
    }
    response = requests.post(url, headers=headers, data=data, files=files)

result = response.json()

print("\nFull Transcript:\n", result.get("text", ""))


def group_speaker_segments(words, max_words_per_line=12):
    """Groups transcript by speaker and wraps lines after max_words_per_line."""
    grouped_transcript = []
    current_speaker = None
    current_line = []
    start_time = None
    end_time = None

    for w in words:
        speaker = w.get("speaker", w.get("speaker_id", "Unknown"))
        word_text = w.get("text", "").strip()
        word_start = w.get("start")
        word_end = w.get("end")

        if not word_text or word_start is None or word_end is None:
            continue

        if current_speaker is None:
            # First word
            current_speaker = speaker
            start_time = word_start
            end_time = word_end
            current_line = [word_text]
        elif speaker == current_speaker:
            # Same speaker
            current_line.append(word_text)
            end_time = word_end

            if len(current_line) >= max_words_per_line:
                grouped_transcript.append({
                    "speaker": current_speaker,
                    "start": start_time,
                    "end": end_time,
                    "text": " ".join(current_line)
                })
                current_line = []
                start_time = word_start  # start new block from this word
        else:
            # Speaker changed — flush current lines
            if current_line:
                grouped_transcript.append({
                    "speaker": current_speaker,
                    "start": start_time,
                    "end": end_time,
                    "text": " ".join(current_line)
                })

            # Start new speaker block
            current_speaker = speaker
            current_line = [word_text]
            start_time = word_start
            end_time = word_end

    # Flush last line
    if current_line:
        grouped_transcript.append({
            "speaker": current_speaker,
            "start": start_time,
            "end": end_time,
            "text": " ".join(current_line)
        })

    return grouped_transcript


# Process only if words exist
if "words" in result:
    grouped_transcript = group_speaker_segments(result["words"], max_words_per_line=12)

    print("\nDiarized Transcript (Max 12 words per line):\n")
    for segment in grouped_transcript:
        start = f"{segment['start']:.2f}" if segment['start'] is not None else "?"
        end = f"{segment['end']:.2f}" if segment['end'] is not None else "?"
        print(f"Speaker {segment['speaker']} ({start}s - {end}s): {segment['text']}")
else:
    print("No word-level data found in response.")
# Out:
# Full Transcript:
#  (परिचय गीत बजता है) तुम ना होते तो एक भी कदम मैं तो चलता नहीं। तुमसे ही मिली है मुझे आज एक नई जिंदगी। सच मैं कहता हूं इस जहां में है तुम सा कोई नहीं। एक पल के लिए तुम्हारे बिन मुझको जीना नहीं। हो मेरी जान तुम पापा। मेरे भगवान तुम पापा। (लल्लन सिंह और शुभांशु दत्त की संगीत बजता है) अरे प्यारे अंकल आप मुझे कहां लेकर जा रहे हो? ओए तू चलता सही। एँटे खड़ा जा, एँटे खड़ा जा। एं.. एं... उध्द देख। (बैकग्राउंड में संगीत बजता है) (हंसते हुए) थैंक यू पापा, थैंक यू सो मच। यू लाइक इट? या आई रियली लाइक इट। चलाएगा? हां पापा। कमान सिट। अअअ आह! रेडी? येस पापा। ओके। कमन लेट्स गो। यस। हां टर्न, टर्न शाबाश, शाबाश करण, शाबाश। हां, हां डरना मत। डर मत, डर मत। कमॉन। टर्न, टर्न, टर्न, टर्न। अबे मैं चला लूंगा। बेटा तू गिरेगा। पापा छोड़िए मैं खुद चला लूंगा। नहीं बेटा तू गिर जाएगा, सभ्य रखें। पापा प्लीज छोड़िए। छोड़ दूं में? हा प्लीज। ओके। सम्भाल के करण, सम्भाल के। अरे किसी को ठोक, भोंप मत करना। अरे साधु अच्छा सम्भाल के चला देगा, तू चिंता काहे को करता है। करण! चल, चल, चल कर लस्सी पीते हैं। (बाइक की आवाज) पॉपलेट वाली पॉपलेट, ताजा ताजा पॉपलेट। पॉपलेट। (किसी चीज के गिरने की आवाज आती है) (चिल्लाते हुए) अरे कहे गया ओ जाते वाला। अरे ब्रेक नहीं सकते हम। अरे तू जी मार्चिंग टैंक। अरे भागा। अरे नीचे को देख। अरे धक्का मार चुका है डांटी दबा। ओके थैंक यू। (टायर के ट्रैक चपेट करने की आवाज आती है) (चिल्लाते हुए) आइगा! सत्यानाश हो तेरा हल्की, मेरा पूरा मर्ची गिराया ना। छोडूंगी ना मैं तेरेको। हल्की धड़के कहां रहे? (किसी चीज के गिरने की आवाज आती है) अरे घोड़-घोड़े तो इधर आ बकला। अरे थॉप! अरे डार्लिंग खाओ ना अरे लो ना। काम हो रहा है तुम्हारा। अरे चेकडम भागते कहां है? सॉरी डार्लिंग। (मारपीट की आवाज आती है) अरे तू! अरे चेकडम थाप! (मारपीट की आवाज आती है) आहिल्ला सॉरी अंकल। (हंसते हुए) बुद्धू को थाप। अरे झींगे! (मारपीट की आवाज आती है) अब तू बच के कहां जाएगा? हाँ हाँ ज्यूरो झींगे अब तू आया ना मेरे नेट में। अब देख मैं कैसे तेरा छील कर निकलती है। माफ करना गलती हो गई मौसी। मौसी! उन्नीस साल की लड़की को मौसी बुलाता है। मैं तेरी मां की बहन लगती है क्या? तेरे को तो... हवलदार! कहाँ है? हवलदार कहाँ है? हाँ? (मारपीट की आवाज आती है) बता दिया मैं तुझे। मैं तेरी मां के भाइंड लगती है क्या? मैं तेरे को तो... हवलदार! कहाँ है हवलदार? कहाँ है? हाँ? (मारपीट की आवाज आती है) बता दिया मैं तुझे। मैं तेरी मां के भाइंड लगती हूँ, छोडूंगी नहीं। (मारपीट की आवाज आती है) अरे जगा, अरे वो हाँ करो, वो हाँ करो। (मारपीट की आवाज आती है) आही! क्या? मैं तेरे को अब छोडूंगी नहीं। कमान ले तू। अरे गवाया! अरे गोली तेरी मार दूं। एक मिनट, एक मिनट, एक मिनट। अरे कीम बगवा रहा हो तू? अरे देखिए, देखिए मेरी बात सुनिए। देखिए। अरे आंटा, क्यों कर रही हो? अरे भाग क्यों रही हो? अरे,अरे रुको, रुको, रुको। (मारपीट की आवाज आती है) मैं तुम्हारी मदद करने की कोशिश कर रहा हूं। अरे जल्दी निकलो मेरे को सांस नहीं आ रहा है। अरे आ जाएगी तुम सीधी खड़ी रहो। एक मिनट। (मारपीट की आवाज आती है) अरे अटक गया। अरे जल्दी निकल दो। अरे ये अंडा अटक कैसे गया? (भिंडी की मिर्च की आवाज आती है) आह, आह, आह। अह! (बैकग्राउंड में इलेक्ट्रिक धुन बजती है) आइगा हिम्मोर्गी बिजली। (पानी की तरह डूब गया)  (बच्चे को पानी से निकालते हुए) सॉरी। माफी काहे को मांगता है? अच्छा लगा मिले तो।
#
# Diarized Transcript (Max 12 words per line):
#
# Speaker speaker_0 (0.00s - 12.24s): (परिचय गीत बजता है) तुम ना होते तो एक भी कदम मैं तो चलता नहीं।
# Speaker speaker_0 (10.14s - 23.18s): तुमसे ही मिली है मुझे आज एक नई जिंदगी। सच मैं कहता
# Speaker speaker_0 (22.22s - 31.96s): हूं इस जहां में है तुम सा कोई नहीं। एक पल के
# Speaker speaker_0 (31.52s - 42.64s): लिए तुम्हारे बिन मुझको जीना नहीं। हो मेरी जान तुम पापा। मेरे
# Speaker speaker_0 (42.00s - 51.62s): भगवान तुम पापा। (लल्लन सिंह और शुभांशु दत्त की संगीत बजता है) अरे प्यारे अंकल आप मुझे कहां लेकर जा
# Speaker speaker_0 (51.54s - 52.02s): रहे हो? ओए तू चलता सही। एँटे खड़ा जा, एँटे खड़ा जा।
# Speaker speaker_0 (52.02s - 52.34s): एं.. एं... उध्द देख। (बैकग्राउंड में संगीत बजता है) (हंसते हुए) थैंक यू पापा, थैंक यू सो
# Speaker speaker_0 (52.34s - 52.34s): मच। यू लाइक इट? या आई रियली लाइक इट। चलाएगा? हां पापा।
# Speaker speaker_0 (52.34s - 52.34s): कमान सिट। अअअ आह! रेडी? येस पापा। ओके। कमन लेट्स गो। यस।
# Speaker speaker_0 (52.34s - 52.34s): हां टर्न, टर्न शाबाश, शाबाश करण, शाबाश। हां, हां डरना मत। डर
# Speaker speaker_0 (52.34s - 52.34s): मत, डर मत। कमॉन। टर्न, टर्न, टर्न, टर्न। अबे मैं चला लूंगा।
# Speaker speaker_0 (52.34s - 52.34s): बेटा तू गिरेगा। पापा छोड़िए मैं खुद चला लूंगा। नहीं बेटा तू
# Speaker speaker_0 (52.34s - 52.34s): गिर जाएगा, सभ्य रखें। पापा प्लीज छोड़िए। छोड़ दूं में? हा प्लीज।
# Speaker speaker_0 (52.34s - 52.34s): ओके। सम्भाल के करण, सम्भाल के। अरे किसी को ठोक, भोंप मत
# Speaker speaker_0 (52.34s - 52.34s): करना। अरे साधु अच्छा सम्भाल के चला देगा, तू चिंता काहे को
# Speaker speaker_0 (52.34s - 52.34s): करता है। करण! चल, चल, चल कर लस्सी पीते हैं। (बाइक की आवाज)
# Speaker speaker_1 (52.34s - 52.34s): पॉपलेट वाली पॉपलेट, ताजा ताजा पॉपलेट। पॉपलेट। (किसी चीज के गिरने की आवाज आती है) (चिल्लाते हुए) अरे कहे गया
# Speaker speaker_1 (52.34s - 52.34s): ओ जाते वाला। अरे ब्रेक नहीं सकते हम। अरे तू जी मार्चिंग
# Speaker speaker_1 (52.34s - 52.34s): टैंक। अरे भागा। अरे नीचे को देख। अरे धक्का मार चुका है
# Speaker speaker_1 (52.34s - 52.34s): डांटी दबा। ओके थैंक यू। (टायर के ट्रैक चपेट करने की आवाज आती है) (चिल्लाते हुए) आइगा! सत्यानाश हो तेरा हल्की,
# Speaker speaker_1 (52.34s - 52.34s): मेरा पूरा मर्ची गिराया ना। छोडूंगी ना मैं तेरेको। हल्की धड़के कहां
# Speaker speaker_1 (52.34s - 52.34s): रहे? (किसी चीज के गिरने की आवाज आती है) अरे घोड़-घोड़े तो इधर आ बकला। अरे थॉप! अरे डार्लिंग
# Speaker speaker_1 (52.34s - 52.34s): खाओ ना अरे लो ना। काम हो रहा है तुम्हारा। अरे चेकडम
# Speaker speaker_1 (52.34s - 52.34s): भागते कहां है? सॉरी डार्लिंग। (मारपीट की आवाज आती है) अरे तू! अरे चेकडम थाप! (मारपीट की आवाज आती है)
# Speaker speaker_1 (52.34s - 52.34s): आहिल्ला सॉरी अंकल। (हंसते हुए) बुद्धू को थाप। अरे झींगे! (मारपीट की आवाज आती है) अब तू
# Speaker speaker_1 (52.34s - 52.34s): बच के कहां जाएगा? हाँ हाँ ज्यूरो झींगे अब तू आया ना
# Speaker speaker_1 (52.34s - 52.34s): मेरे नेट में। अब देख मैं कैसे तेरा छील कर निकलती है।
# Speaker speaker_1 (52.34s - 52.34s): माफ करना गलती हो गई मौसी। मौसी! उन्नीस साल की लड़की को
# Speaker speaker_1 (52.34s - 52.34s): मौसी बुलाता है। मैं तेरी मां की बहन लगती है क्या? तेरे
# Speaker speaker_1 (52.34s - 52.34s): को तो... हवलदार! कहाँ है? हवलदार कहाँ है? हाँ? (मारपीट की आवाज आती है) बता दिया
# Speaker speaker_1 (52.34s - 52.34s): मैं तुझे। मैं तेरी मां के भाइंड लगती है क्या? मैं तेरे
# Speaker speaker_1 (52.34s - 52.34s): को तो... हवलदार! कहाँ है हवलदार? कहाँ है? हाँ? (मारपीट की आवाज आती है) बता दिया
# Speaker speaker_1 (52.34s - 52.34s): मैं तुझे। मैं तेरी मां के भाइंड लगती हूँ, छोडूंगी नहीं। (मारपीट की आवाज आती है)
# Speaker speaker_1 (52.34s - 52.34s): अरे जगा, अरे वो हाँ करो, वो हाँ करो। (मारपीट की आवाज आती है) आही! क्या?
# Speaker speaker_1 (52.34s - 52.34s): मैं तेरे को अब छोडूंगी नहीं। कमान ले तू। अरे गवाया! अरे
# Speaker speaker_1 (52.34s - 52.68s): गोली तेरी मार दूं। एक मिनट, एक मिनट, एक मिनट। अरे कीम
# Speaker speaker_1 (52.68s - 53.18s): बगवा रहा हो तू? अरे देखिए, देखिए मेरी बात सुनिए। देखिए। अरे
# Speaker speaker_1 (52.86s - 248.80s): आंटा, क्यों कर रही हो? अरे भाग क्यों रही हो? अरे,अरे रुको,
# Speaker speaker_1 (248.04s - 252.08s): रुको, रुको। (मारपीट की आवाज आती है) मैं तुम्हारी मदद करने की कोशिश कर रहा हूं।
# Speaker speaker_1 (252.02s - 255.36s): अरे जल्दी निकलो मेरे को सांस नहीं आ रहा है। अरे आ
# Speaker speaker_1 (255.22s - 262.38s): जाएगी तुम सीधी खड़ी रहो। एक मिनट। (मारपीट की आवाज आती है) अरे अटक गया। अरे
# Speaker speaker_1 (262.12s - 269.20s): जल्दी निकल दो। अरे ये अंडा अटक कैसे गया? (भिंडी की मिर्च की आवाज आती है) आह, आह,
# Speaker speaker_1 (269.18s - 298.08s): आह। अह! (बैकग्राउंड में इलेक्ट्रिक धुन बजती है) आइगा हिम्मोर्गी बिजली। (पानी की तरह डूब गया) (बच्चे को पानी से निकालते हुए) सॉरी। माफी काहे को
# Speaker speaker_1 (298.02s - 299.98s): मांगता है? अच्छा लगा मिले तो।
